# %%
import json
import pandas as pd
import re

# %%
# Opening main Qulac JSON file
with open('qulac.json') as json_file:
    data = json.load(json_file)

    print("Type:", type(data))
# Out:
# Type: <class 'dict'>

# %%
# Open Qulac history
with open('qulac_hist012_dict.json') as json_file:
    history = json.load(json_file)

# %%
def process_qulac_for_wiki(data_df):
    """
    Process Qulac main dataset into a dictionary grouped by topic ('user queries') and lists of associated facets ('user intent').
    
    {topic:[
        facet,
        facet,
        ...
        ],
    topic:[
        facet,
        facet,
        ...
        ],
    ...
    }
    """
    structured_data = {}

    for _, row in data_df.iterrows():
        topic = row["topic"]
        facet_desc = row["facet_desc"]

        # Preprocess facet desc
        facet_desc = facet_desc.lower()
        facet_desc = facet_desc.strip()

        # Initialise topic if doesn't exist
        if topic not in structured_data:
            structured_data[topic] = []

        # Add facet if doesn't exist
        if facet_desc not in structured_data[topic]:
            structured_data[topic].append(facet_desc)

    return structured_data

# %%
# Process qulac main dataset for assisting to retrieve wiki summaries
qulac_for_wiki = process_qulac_for_wiki(data_df)

# %%
# Save dictionary to JSON
with open("qulac_for_wiki.json", "w", encoding="utf-8") as f:
    json.dump(qulac_for_wiki, f, indent=2)

# %%
# View contents of dictionary
print(json.dumps(qulac_for_wiki, indent=2))
# Out:
# {
#   "obama family tree": [
#     "find the time magazine photo essay \\\"barack obama\\'s family tree\\\".",
#     "where did barack obama\\'s parents and grandparents come from?",
#     "find biographical information on barack obama\\'s mother."
#   ],
#   "cheap internet": [
#     "what are some low-cost broadband internet providers?",
#     "do any internet providers still sell dial-up?",
#     "who can provide inexpensive digital cable television bundled with internet service?",
#     "find me some providers of free wireless internet access.",
#     "i want to find cheap dsl providers.",
#     "is there a way to get internet access without phone service?"
#   ],
#   "ritz carlton lake las vegas": [
#     "find information about the ritz carlton resort at lake las vegas.",
#     "find a site where i can determine room price and availability.",
#     "find directions to the ritz carlton lake las vegas.",
#     "find reviews of the ritz carlton lake las vegas."
#   ],
#   "fickle creek farm": [
#     "find general information about fickle creek farm in north carolina",
#     "where is fickle creek farm, and how can i go there?",
#     "what products do they grow and/or raise there?",
#     "where can i buy products that come from fickle creek farm?",
#     "find information about staying at the bed and breakfast at fickle creek farm."
#   ],
#   "madam cj walker": [
#     "find historical information about madam c. j. walker.",
#     "find information about the business that c. j. walker started.",
#     "find information about c. j. walker\\'s involvement in the political and social issues of her day."
#   ],
#   "indiana child support": [
#     "find the official legal rules and procedures pertaining to child support in indiana.",
#     "help me calculate my child support obligation in indiana.",
#     "find law firms that offer services relevant to child support in indiana."
#   ],
#   "sonoma county medical services": [
#     "what medical services are available in sonoma county, california?",
#     "i\\'m looking for the home page of the county medical services program (cmsp) of sonoma county, california.",
#     "i am looking for more information about health care coverage for low-income residents ofsonoma county, ca."
#   ],
#   "universal animal cuts reviews": [
#     "find testimonials of universal animal cuts nutritional supplement.",
#     "are animal cuts safe to use, and are they effective?",
#     "sites that sell universal animal cuts that include product reviews."
#   ],
#   "cass county missouri": [
#     "find demographic information about cass county, mo.",
#     "what was the 2008 budget for cass county, mo?",
#     "i am looking for newcomer information for cass county, missouri.",
#     "information about zoning regulations in cass county, missouri.",
#     "what tourist attractions are in cass county, mo?",
#     "historical facts about cass county, missouri."
#   ],
#   "ralph owen brewster": [
#     "find biographical information about ralph owen brewster.",
#     "what elected offices did ralph owen brewster hold?",
#     "what was the relationship between howard hughes and ralph owen brewster?"
#   ],
#   "mayo clinic jacksonville fl": [
#     "what medical services are available at the mayo clinic in jacksonville, fl?",
#     "how does one request an appointment at the mayo clinic in jacksonville, florida?",
#     "find the contact information for the mayo clinic in jacksonville, fl.",
#     "housing information for outpatients of the mayo clinic in jacksonville, fl."
#   ],
#   "gmat prep classes": [
#     "who are some companies that offer gmat prep classes?",
#     "i\\'m looking for some free sample gmat exams to practice on.",
#     "i\\'d like to find some tips to help me do well on the gmat.",
#     "i\\'m looking for the beatthegmat blog and forums.",
#     "take me to the veritasprep home page.",
#     "what\\'s the difference between the gre and the gmat?"
#   ],
#   "map of brazil": [
#     "what are the boundaries of the political jurisdictions in brazil?",
#     "i am looking for information about taking a vacation trip to brazil.",
#     "i want to buy a road map of brazil."
#   ],
#   "lymphoma in dogs": [
#     "what treatments are available for dogs diagnosed with lymphoma?",
#     "what are the symptoms of lymphoma in dogs?",
#     "what are the risk factors or causes of lymphoma in dogs?"
#   ],
#   "kenmore gas water heater": [
#     "reviews of kenmore gas water heaters",
#     "owner manuals for kenmore (sears) gas water heaters",
#     "information about kenmore gas water heaters: specifically, features, energy consumption and safety thereof",
#     "retailers of and price information for kenmore gas water heaters"
#   ],
#   "hp mini 2140": [
#     "retailers, including price information, of the hp mini 2140 notebook computer",
#     "product reviews for the hp mini 2140 notebook computer",
#     "technical specifications of the hp mini 2140 notebook computer"
#   ],
#   "adobe indian houses": [
#     "how does one build an adobe house?",
#     "information about indian tribes that used adobe houses",
#     "i\\'d like to order books or videos/cds about how to construct adobe buildings."
#   ],
#   "pacific northwest laboratory": [
#     "career opportunities at pnl: what openings are currently available, what educational background is required, what prior experience is needed",
#     "types of research projects performed at pnl",
#     "home page of the pacific northwest national laboratory",
#     "information about the scientific user facilities of the laboratory",
#     "who operates (manages) pnl?"
#   ],
#   "california franchise tax board": [
#     "find information about the california franchise tax board.",
#     "how do i register as a tax preparer?",
#     "find contact information for the california ftb.",
#     "find tax forms and other information on filing individual taxes."
#   ],
#   "dangers of asbestos": [
#     "what specific health problems arise from exposure to asbestos?",
#     "find basic information about the dangers of asbestos.",
#     "find mortality rates due to asbestos exposure."
#   ],
#   "poem in your pocket day": [
#     "what is \\\"poem in your pocket day\\\"?",
#     "find poems written for poem in your pocket day.",
#     "find ideas for how to celebrate poem in your pocket day and national poetry month.",
#     "find specific events in new york city connected to poem in your pocket day."
#   ],
#   "interview thank you": [
#     "get help on writing a thank-you letter after a job interview.",
#     "find examples of thank-you letters for sending after an interview.",
#     "how can i best end a job interview positively?"
#   ],
#   "djs": [
#     "i\\'m looking for djs that specialize in hip-hop music.",
#     "i want to hire a dj for a wedding.",
#     "how do i become a radio disc jockey?",
#     "what jobs are available for disc jockeys?"
#   ],
#   "tv on computer": [
#     "looking for information on how to watch television programming on your computer.",
#     "how much does it cost to get tv programs online?",
#     "get technical help for watching tv programs on the computer.",
#     "find television channels and shows that i can watch online on my computer."
#   ],
#   "sit and reach test": [
#     "find out what the \\\"sit and reach test\\\" is.",
#     "how is this test used in physical rehabilitation treatment?",
#     "how is the sit and reach test properly done?",
#     "what does the sit and reach test measure?"
#   ],
#   "culpeper national cemetery": [
#     "what is the history of the culpeper national cemetery?",
#     "where is the culpeper national cemetery located?",
#     "information regarding who can be buried at culpeper national cemetery"
#   ],
#   "von willebrand disease": [
#     "what is von willebrand disease?",
#     "what are the symptoms of von willebrand disease?",
#     "what treatments exist for von willebrand disease?"
#   ],
#   "bowflex power pro": [
#     "find information about the bowflex power pro.",
#     "find reviews of the bowflex power pro.",
#     "find recall notices for the bowflex power pro.",
#     "find a retailer from whom i can buy a bowflex power pro."
#   ],
#   "butter and margarine": [
#     "what is the difference between butter and margarine?",
#     "what is the difference in regards to cholesterol, calorie count, and other nutritional qualities.",
#     "how are butter and margarine made?"
#   ],
#   "us capitol map": [
#     "find a map of the inside of the us capitol.",
#     "find a map of the area around the us capitol, including nearby sites to visit."
#   ],
#   "dutchess county tourism": [
#     "find information for tourists about dutchess county, ny.",
#     "find the homepage of dutchess county (ny) tourism."
#   ],
#   "atypical squamous cells": [
#     "what do atypical squamous cells mean on a pap smear test?",
#     "find information on cervical cancer, atypical squamous cells, and human papillomavirus (hpv).",
#     "how often may atypical squamous cells predict cervical cancer?"
#   ],
#   "iowa food stamp program": [
#     "find general information about iowa\\'s food stamps program.",
#     "how do i apply for iowa\\'s food assistance (food stamps) program?",
#     "find the homepage for iowa\\'s food assistance program?",
#     "find statistics for the food stamp program in iowa."
#   ],
#   "map": [
#     "take me to the google maps homepage.",
#     "i want to find free printable maps.",
#     "i want to find sources for satellite maps and live satellite photos.",
#     "i\\'m looking for an online world atlas."
#   ],
#   "fact on uranus": [
#     "find information about the planet uranus.",
#     "find the wikipedia page on uranus.",
#     "find information on uranus suitable for elementary-to-middle school students, such as lesson content or interactive sites.",
#     "what do we know about uranus, versus what open questions are there about the planet?"
#   ],
#   "equal opportunity employer": [
#     "what does the phrase, \\\"equal opportunity employer\\\" mean?",
#     "whom can i contact if i think i am being discriminated against by an equal opportunity employer?",
#     "find the homepage of the equal employment opportunity commission."
#   ],
#   "mothers day songs": [
#     "lyrics of songs written for mothers\\' day",
#     "names of artists who have recorded songs about mother\\'s day"
#   ],
#   "all men are created equal": [
#     "who said \\\"all men are created equal\\\"?",
#     "information about the drafting of the declaration of independence",
#     "image of the declaration of independence at the national archives",
#     "how has the phrase \\\"all men are created equal\\\" been interpreted over time by the us surpreme court?",
#     "quotes about independence"
#   ],
#   "electronic skeet shoot": [
#     "what different types of electronic skeet shooting games are available?",
#     "product reviews for electronic skeet shooting games",
#     "retailers selling electronic skeet shooting games with price information",
#     "information about product recalls for electronic skeet shooting games"
#   ],
#   "source of the nile": [
#     "how to play the board game \\\"source of the nile\\\"",
#     "information on the feud between speke and burton over the discovery of the source of the nile river",
#     "map of the nile river basin"
#   ],
#   "american military university": [
#     "what are the registration requirements for enrolling at american military university?",
#     "reviews and commentary on the quality of education received by students at american military university",
#     "find the home page of the american military university"
#   ],
#   "rock and gem shows": [
#     "looking for locations and dates of rock and gem shows.",
#     "rock and gem shows that offer lapidary classes",
#     "information on clubs that host rock and gem shows"
#   ],
#   "jax chemical company": [
#     "contact information for jax chemical company",
#     "find the home page of the jax chemical company",
#     "what type of surface treatment products does jax chemical company manufacture?",
#     "who are retailers that sell jax chemical company\\'s green patina solution?"
#   ],
#   "rocky mountain news": [
#     "discussion of the impending sale of the rocky mountain news",
#     "home page of the rocky mountain news",
#     "who are the sports reporters for the rocky mountain news?"
#   ],
#   "dinosaurs": [
#     "go to the discovery channel\\'s dinosaur site, which has pictures of dinosaurs and games.",
#     "i\\'m looking for free pictures of dinosaurs.",
#     "i want to find pictures of dinosaurs that i can color in, as in a coloring book.",
#     "i\\'m looking for a list of all (or many of) the different kinds of dinosaurs, with pictures."
#   ],
#   "east ridge high school": [
#     "demographics of east ridge high school in lick creek, kentucky",
#     "home page for east ridge high school in chattanooga, tennessee",
#     "information about the sports program at east ridge high school in clermont, florida",
#     "description of the sports facilities at east ridge high school in woodbury, mn"
#   ],
#   "va dmv registration": [
#     "information and procedures for registering vehicles in virginia",
#     "where are offices of the virginia department of motor vehicles located and what are their hours of operation?",
#     "home page of the virginia department of motor vehicles"
#   ],
#   "illinois state tax": [
#     "information about the sales tax in illinois: what is the rate and what is it levied on",
#     "information on the state income tax in illinois",
#     "find a site where i can download illinois state tax forms"
#   ],
#   "arkadelphia health club": [
#     "locations and reviews of health clubs in arkadelphia, arkansas",
#     "information regarding the locations of and services/facilities provided by the arkadelphia health club"
#   ],
#   "trombone for sale": [
#     "information on where i could buy a new or used trombone",
#     "good places to sell a used trombone"
#   ],
#   "vines for shade": [
#     "information on vines that can be grown in shady areas",
#     "ideas on using plant vines to shade an area on or around my house from the sun, like training them on an inexpensive trellis or up a wall or fence"
#   ],
#   "sherwood regional library": [
#     "what services are provided by the sherwood regional library?",
#     "driving directions to the sherwood regional library",
#     "what are the hours of operation of the sherwood regional library?"
#   ],
#   "tangible personal property tax": [
#     "what is the definition of tangible personal property for tax purposes?",
#     "what states levy a tax against tangible personal property?",
#     "when is the tangible personal property tax due?"
#   ],
#   "martha stewart and imclone": [
#     "find information/timeline about martha stewart\\'s insider trading case",
#     "find sites that support martha stewart with respect to the insider trading case",
#     "opinions regarding the insider trading case brought against martha stewart",
#     "looking for information on martha stewart\\'s involvement with imclone"
#   ],
#   "uplift at yellowstone national park": [
#     "how likely is a volcanic eruption at yellowstone national park, and what would be the effects of such an eruption?",
#     "information on ground elevation changes and movement resulting from ongoing low-level geothermal activity at yellowstone national park",
#     "home page for the yellowstone volcano observatory"
#   ],
#   "espn sports": [
#     "i\\'m looking for college football and basketball scores.",
#     "i want to find nba basketball standings.",
#     "i\\'m looking for baseball scores and information on upcoming live broadcast games.",
#     "i\\'m looking for information on nascar races.",
#     "i\\'m looking for information on fantasy football leagues."
#   ],
#   "tn highway patrol": [
#     "what are the requirements to become a tennessee highway patrol state trooper?",
#     "information about the responsibilities of the tennessee highway patrol",
#     "home page of the tennessee highway patrol",
#     "i want to fill in the customer satisfaction survey about my interaction with a tennessee highway patrol state trooper."
#   ],
#   "403b": [
#     "what is a 403b plan?",
#     "who is eligible for a 403b plan?",
#     "what are the rules for a 403b retirement plan?",
#     "what is the difference between 401k and 403b retirement plans?",
#     "what are the withdrawal limitations for a 403b retirement plan?"
#   ],
#   "angular cheilitis": [
#     "what home remedies are there for angular cheilitis?",
#     "what causes angular cheilitis?",
#     "what is the common name for angular cheilitis?",
#     "how do you treat severe angular cheilitis?"
#   ],
#   "pocono": [
#     "find general information on tourist activities in pennsylvania\\'s pocono mountains.",
#     "find a map showing lodgings in the poconos pa region.",
#     "find information about the pocono raceway in pennsylvania.",
#     "find information about the split rock resort in the poconos."
#   ],
#   "figs": [
#     "find information on nutritional or health benefits of figs.",
#     "find recipes that use figs.",
#     "find information on the different varieties of figs.",
#     "find information on growing figs."
#   ],
#   "last supper painting": [
#     "find a picture of the last supper painting by leonardo da vinci.",
#     "are tickets available online to view da vinci\\'s last supper in milan, italy?",
#     "what is the significance of da vinci\\'s interpretation of the last supper in catholicism?"
#   ],
#   "university of phoenix": [
#     "what online programs are offered by the university of phoenix?",
#     "find reviews of the programs at the university of phoenix.",
#     "who are the main online competitors of the university of phoenix?",
#     "find homepages of faculty members at the university of phoenix."
#   ],
#   "the beatles rock band": [
#     "find a listing of beatles songs.",
#     "what is the history of the beatles rock band?",
#     "what albums did the beatles release?",
#     "what are the names of the members of the beatles?"
#   ],
#   "septic system design": [
#     "how does a septic system work?",
#     "what alternatives are there for the design of a septic system?",
#     "what maintenance does a septic system require?",
#     "i need a septic system contractor."
#   ],
#   "porterville": [
#     "what k-12 schools are in porterville, ca?",
#     "what colleges or post-secondary institutions are in porterville, ca?",
#     "what medical care is available in porterville, ca?",
#     "find information about the panthers sports teams at porterville high school in california.",
#     "find the homepage of the porterville recorder newspaper."
#   ],
#   "arizona game and fish": [
#     "take me to the arizona game and fish department homepage.",
#     "what are the regulations for hunting and fishing in arizona?",
#     "i\\'m looking for the arizona fishing report site.",
#     "i\\'d like to find guides and outfitters for hunting trips in arizona."
#   ],
#   "grilling": [
#     "find kabob recipes.",
#     "find tips on grilling vegetables.",
#     "find tips on grilling fish.",
#     "find instructions for grilling chicken.",
#     "find the grilling magazine website.",
#     "find information on gas barbecue grills and cooking on a gas grill."
#   ],
#   "furniture for small spaces": [
#     "what are some small space decorating dos and don\\'ts?",
#     "what is the effect of mirrored surfaces in small spaces?",
#     "how does furniture arrangement create an illusion of more space?",
#     "how important is the scale of furniture in small spaces?"
#   ],
#   "dnr": [
#     "what are \\\"do not resuscitate\\\" orders and how do you get one in place?",
#     "what is required to get a hunting license online from the michigan department of natural resources?",
#     "what are the maryland department of natural resources\\' regulations for deer hunting?"
#   ],
#   "arkansas": [
#     "provide arkansas tourist information.",
#     "show a map of arkansas.",
#     "provide information on the city of little rock, arkansas.",
#     "find information on colleges and universities in arkansas."
#   ],
#   "hobby stores": [
#     "what hobby stores carry trains?",
#     "find a list of hobby stores in maryland.",
#     "where can i buy radio-controlled planes?",
#     "what is the website for hobbytown usa?"
#   ],
#   "blue throated hummingbird": [
#     "find a picture of a blue-throated hummingbird.",
#     "what is the scientific name of the blue-throated hummingbird?",
#     "what are the migration patterns of the blue-throated hummingbird?",
#     "the blue-throated hummingbird is native to what areas?"
#   ],
#   "computer programming": [
#     "what type of careers are there for computer programmers?",
#     "list online computer programming tutorials.",
#     "what\\'s in a computer science degree program?",
#     "what is the average salary for a computer programmer?",
#     "what computer programming languages are there?"
#   ],
#   "barbados": [
#     "find information on barbados history.",
#     "find a map of barbados.",
#     "what does the barbados flag look like?",
#     "suggest tourist activities in barbados.",
#     "find the barbados underground homepage.",
#     "find information on barbados prime minister david thompson."
#   ],
#   "lipoma": [
#     "what are the causes of lipoma tumors in humans?",
#     "what age group most often exhibits lipomas?",
#     "which animals are known to present lipomas?",
#     "find pictures of lipoma tumors.",
#     "what are the treatments for malignant lipolysis?"
#   ],
#   "battles in the civil war": [
#     "what were the major battles in the us civil war?",
#     "what famous generals fought in the us civil war?",
#     "find a timeline or map of us civil war battles.",
#     "what movies have been made about us civil war battles?"
#   ],
#   "poker tournaments": [
#     "i want to find information on the world series of poker.",
#     "i\\'m looking for a schedule of poker tournaments in las vegas.",
#     "take me to the full tilt poker website.",
#     "i\\'m looking for a schedule of poker tournaments in atlantic city.",
#     "i want to find texas hold-em tournaments.",
#     "find books on tournament poker playing."
#   ],
#   "scooters": [
#     "find kids\\' scooters for sale.",
#     "find the homepage of hoveround scooters.",
#     "what brands of mobility scooters are available?",
#     "find mopeds for sale."
#   ],
#   "ron howard": [
#     "what movies has ron howard directed?",
#     "find biographical information on director ron howard.",
#     "what television shows did ron howard act in?",
#     "who are ron howard\\'s family members: parents, wife, any children?"
#   ],
#   "becoming a paralegal": [
#     "what training is required to become a paralegal?",
#     "what aba-approved certificate programs are there?",
#     "find the homepage of the paralegal association.",
#     "what are the duties of a paralegal?"
#   ],
#   "hip fractures": [
#     "find information on hip fractures in the elderly.",
#     "how do you treat a hip fracture and what is the prognosis for recovery?",
#     "how many hip fractures occur annually in the us?"
#   ],
#   "rock art": [
#     "where can i learn about rock painting or buy a rock-painting kit?",
#     "where can i buy tools for stone carving or engraving?",
#     "find information on cave paintings in france.",
#     "where can i buy rock and roll posters?",
#     "find information on the artwork used on rock music album covers."
#   ],
#   "signs of a heartattack": [
#     "what are the symptoms of a heart attack?",
#     "do the signs of a heart attack differ between men and women?",
#     "what are the early signs of a heart attack?"
#   ],
#   "weather strip": [
#     "how do you weather strip automobile windows and doors?",
#     "what is the best way to seal or weather strip my garage door?",
#     "how do i weather strip my sliding glass door?"
#   ],
#   "best long term care insurance": [
#     "what are the different types of long term care insurance policies?",
#     "what companies offer long term care insurance policies?",
#     "how much does long term insurance cost?",
#     "what ratings has am best given to long term care insurance polices?"
#   ],
#   "pork tenderloin": [
#     "what time and temperature should be used to roast a pork tenderloin?",
#     "find recipes for pork tenderloin marinades and dry rubs.",
#     "find recipes for pork tenderloin cooked in a crockpot.",
#     "how do i grill a pork tenderloin on a gas grill?"
#   ],
#   "black history": [
#     "find a timeline for african americans in the united states.",
#     "find activities for children for black history month.",
#     "find names of famous african american inventors.",
#     "find maya angelou\\'s poetry."
#   ],
#   "wedding budget calculator": [
#     "i want to find online guides, tips, and checklists for planning a wedding.",
#     "i am looking for spreadsheets or templates to help me tabulate a budget for a wedding.",
#     "i want to find some example wedding budgets.",
#     "i\\'m looking for information on planning a wedding shower, like theme ideas and budget guidelines.",
#     "how can i plan an inexpensive wedding?"
#   ],
#   "newyork hotels": [
#     "find inexpensive hotels in new york city.",
#     "where are hotels on long island, new york?",
#     "i want to book a room in a hotel that\\'s on times square in new york city.",
#     "what luxury hotels are in new york city?"
#   ],
#   "old coins": [
#     "what is a good way to begin collecting old coins?",
#     "what is the value of a rare wheat us penny?",
#     "i\\'m looking for information about old us silver dollars."
#   ],
#   "quit smoking": [
#     "what are the ways you can quit smoking?",
#     "what are the benefits of quitting smoking?",
#     "can you quit smoking using the cold turkey method?",
#     "how can hypnosis help someone quit smoking?"
#   ],
#   "kansas city mo": [
#     "what are some kansas city, mo tourist attractions?",
#     "what hotels are near the kansas city airport?",
#     "find the kansas city chiefs homepage.",
#     "what casinos are in kansas city, missouri?",
#     "find information on the hallmark visitors center in kansas city, mo."
#   ],
#   "civil right movement": [
#     "what issues were addressed in the civil rights act of 1964?",
#     "find a timeline of the civil rights movement in the united states.",
#     "what was martin luther king jr\\'s contribution to the us civil rights movement?",
#     "what is the history of the little rock nine?"
#   ],
#   "credit report": [
#     "how do i get my free annual credit report?",
#     "i need the customer service contact information for the three major credit reporting agencies.",
#     "how do you dispute credit report information?",
#     "how is a credit score determined?"
#   ],
#   "unc": [
#     "what campuses are part of the university of north carolina?",
#     "find reports of university of north carolina chapel hill athletics.",
#     "where is the university of north carolina hospital located?"
#   ],
#   "vanuatu": [
#     "find a map of the islands of vanuatu.",
#     "i need travel and tourism information for vanuatu.",
#     "find photos from the \\\"survivor 9, vanuatu\\\" tv reality series."
#   ],
#   "internet phone service": [
#     "what is the best internet phone service?",
#     "find free internet phone service.",
#     "who provides voip phone service?",
#     "how much does internet phone service cost?"
#   ],
#   "gs pay rate": [
#     "find the general schedule pay tables.",
#     "does the federal wage system affect the general schedule?",
#     "do all us federal government agencies use the general schedule pay tables?"
#   ],
#   "the current": [
#     "i want to find the homepage of the current magazine in san antonio."
#   ],
#   "brooks brothers clearance": [
#     "find brooks brothers online promotional coupons.",
#     "where are brooks brothers outlet stores located?",
#     "is brooks brothers catalog merchandise available at their outlet stores?"
#   ],
#   "churchill downs": [
#     "find information on the racing schedule at churchill downs.",
#     "find information on breeders cup races.",
#     "find information on the kentucky derby museum.",
#     "find the seating chart of churchill downs."
#   ],
#   "condos in florida": [
#     "find beachfront condos for sale in florida.",
#     "i want to find a vacation rental oceanfront condo in florida.",
#     "what condos are for sale in miami beach, florida?"
#   ],
#   "dog clean up bags": [
#     "can i order dog clean-up bags online?",
#     "are there biodegradable products for the disposal of dog waste?",
#     "what are the best ways of disposing of dog waste?"
#   ],
#   "designer dog breeds": [
#     "what breeds of small or toy dog hybrids are there?",
#     "find puppies of designer dog breeds for sale.",
#     "find pictures of various designer dog breeds."
#   ],
#   "pressure washers": [
#     "where can i buy replacement parts for pressure washers?",
#     "provide pressure washer reviews and/or ratings.",
#     "what are the different brands of pressure washers?",
#     "find \\\"the-power-washer-advisor.com\\\" web site."
#   ],
#   "sore throat": [
#     "what causes a sore throat?",
#     "find home remedies for a sore throat.",
#     "find information on throat cancer.",
#     "what does it mean when my throat is sore on only one side?"
#   ],
#   "idaho state flower": [
#     "what is the state flower of idaho?",
#     "find pictures of the idaho state flower.",
#     "find \\\"fun facts\\\" about idaho: state flower, tree, bird, etc."
#   ],
#   "indiana state fairgrounds": [
#     "what events are held at the indiana state fairgrounds?",
#     "find driving directions to the indiana state fairgrounds.",
#     "where can i buy tickets for indiana state fairgrounds events?",
#     "find a map for the indiana state fairgrounds."
#   ],
#   "fybromyalgia": [
#     "what are the primary symptoms or signs of fybromyalgia?",
#     "what medicines can be used to treat fybromyalgia?",
#     "what support groups are there for fybromyalgia suffers?"
#   ],
#   "french lick resort and casino": [
#     "what jobs are available at french lick casino and resort?",
#     "are there discounted packages for staying at french lick resort and casino?"
#   ],
#   "defender": [
#     "find information on the land rover defender sport-utility vehicle.",
#     "i want to go to the homepage for defender marine supplies.",
#     "i\\'m looking for information on defender, an arcade game by williams. is it possible to play it online?",
#     "i\\'d like to find user reports about windows defender, particularly problems with the software."
#   ],
#   "ontario california airport": [
#     "find flight information for the ontario, ca airport.",
#     "what hotels are near the ontario, ca airport?",
#     "what services/facilities does the ontario, ca airport offer?",
#     "what is the address of the ontario, ca airport?"
#   ],
#   "volvo": [
#     "i\\'m looking for volvo\\'s homepage.",
#     "find reviews of the volvo xc90 suv.",
#     "where can i find volvo semi trucks for sale (new or used)?",
#     "find a volvo dealer.",
#     "find an online source for volvo parts."
#   ],
#   "rick warren": [
#     "take me to rick warren\\'s homepage.",
#     "i\\'m looking for the homepage for rick warren\\'s book, \\\"the purpose driven life\\\".",
#     "i\\'m looking for background and biographical information on rick warren.",
#     "i want to see articles and web pages about the controversy over rick warren\\'s invocation at the obama inauguration.",
#     "i want to read about the debate between john mccain and barack obama hosted by rick warren."
#   ],
#   "yahoo": [
#     "take me to yahoo! mail.",
#     "take me to yahoo! finance.",
#     "i want to log in to my yahoo! account.",
#     "find information about yahoo!, the company."
#   ],
#   "diversity": [
#     "how is workplace diversity achieved and managed?",
#     "find free activities and materials for running a diversity training program in my office.",
#     "what is cultural diversity? what is prejudice?",
#     "find quotes, poems, and/or artwork illustrating and promoting diversity."
#   ],
#   "euclid": [
#     "find information on the greek mathematician euclid.",
#     "i\\'m looking for a source for euclid truck parts.",
#     "take me to the homepage for the euclid chemical company."
#   ],
#   "lower heart rate": [
#     "what causes the heart to beat faster or slower?",
#     "what is a normal heart rate when a person is resting?",
#     "how can i lower my heart rate?",
#     "is a higher heart rate related to high blood pressure or cholesterol?"
#   ],
#   "starbucks": [
#     "take me to the starbucks homepage.",
#     "what is the balance on my starbucks gift card?",
#     "find calorie counts and other nutritional information about starbucks products.",
#     "find recipes from starbucks, either for making or using starbucks products.",
#     "i\\'m looking for locations of starbucks stores worldwide."
#   ],
#   "inuyasha": [
#     "i\\'m looking for pictures and wallpaper images from inuyasha.",
#     "find inuyasha anime episodes for download.",
#     "find games based on the inuyasha series, either online or for game systems.",
#     "i\\'m looking for inuyasha fan forums and websites.",
#     "find music from the inuyasha television series."
#   ],
#   "ps 2 games": [
#     "find reviews of playstation 2 games.",
#     "where can i find cheat codes for playstation 2 games?",
#     "i\\'m looking for sites that announce new playstation 2 games.",
#     "where can i buy used playstation 2 games?",
#     "what are the specifications of the playstation 2 console?"
#   ],
#   "getting organized": [
#     "find tips on getting organized, both reducing clutter and managing time.",
#     "take me to the container store homepage.",
#     "find catalogs of office supplies for organization and decluttering."
#   ],
#   "diabetes education": [
#     "find free diabetes education materials such as videos, pamphlets, and books.",
#     "take me to the nih national diabetes education program homepage.",
#     "take me to the american association of diabetes educators homepage.",
#     "i\\'m looking for nutrition and diet information for diabetics.",
#     "how can i become a diabetes educator?"
#   ],
#   "atari": [
#     "i want to read about the history of the atari 2600 and other atari game consoles.",
#     "i am looking for a site where i can play old atari games online.",
#     "find information about classic atari games.",
#     "find information about atari arcade games."
#   ],
#   "website design hosting": [
#     "what are the cheapest web hosting companies? who offers free web hosting?",
#     "where can i register a domain name?",
#     "find sites that offer free dns hosting.",
#     "find reviews of web hosting services, geared towards small business needs.",
#     "i\\'m looking for information and courses on designing web sites."
#   ],
#   "elliptical trainer": [
#     "i\\'m looking for reviews of elliptical machines.",
#     "where can i buy a used or discounted elliptical trainer?",
#     "what are the benefits of an elliptical trainer compared to other fitness machines?",
#     "what are the best elliptical trainers for home use?"
#   ],
#   "cell phones": [
#     "what free phones are available from different vendors?",
#     "find information on prepaid cell phones. what companies offer them? what kind of phones are available?",
#     "what cell phone companies offer motorola phones?",
#     "where can i find information on buying unlocked phones?"
#   ],
#   "hoboken": [
#     "find restaurants in hoboken.",
#     "find the homepage for the city of hoboken, nj.",
#     "i\\'m looking for the history of hoboken, nj.",
#     "i\\'m looking for information on bars and nightclubs in hoboken, nj.",
#     "find real estate listings for hoboken, nj.",
#     "find a street-level map of hoboken, nj."
#   ],
#   "gps": [
#     "find reviews of gps units and car navigation systems.",
#     "find reviews of digital cameras with built-in gps."
#   ],
#   "pampered chef": [
#     "how do i host a pampered chef cooking show?",
#     "how do i become a pampered chef consultant?",
#     "find some recipes from the pampered chef.",
#     "i would like to find reviews of the pampered chef programs, products, and recipes."
#   ],
#   "dogs for adoption": [
#     "find organizations that offer dogs for adoption.",
#     "take me to the homepage of the humane society.",
#     "what should i know about adopting a dog?"
#   ],
#   "disneyland hotel": [
#     "what hotels are near disneyland?",
#     "find information on package deals from hotels near disneyland.",
#     "find reviews of disneyland hotels.",
#     "find special offers such as reduced ticket rates at disneyland."
#   ],
#   "toilet": [
#     "what different kinds of toilets exist, and how do they differ?",
#     "i\\'m looking for companies that manufacture residential toilets.",
#     "where can i buy parts for american standard toilets?",
#     "how do i fix a toilet that isn\\'t working properly?",
#     "what companies manufacture bidets?",
#     "i\\'m looking for a kohler wall-hung toilet. where can i buy one?"
#   ],
#   "michworks": [
#     "what jobs are available in michigan?",
#     "find career resources and information on job seeking in michigan.",
#     "find information about services available to the unemployed in michigan."
#   ],
#   "orange county convention center": [
#     "find a schedule of events taking place at the orange county convention center.",
#     "how do i reserve the orange county convention center for an event?",
#     "what hotels are near the orange county convention center?"
#   ],
#   "the music man": [
#     "find lyrics for songs from the music man.",
#     "find current performances of the music man.",
#     "find recordings of songs from the music man.",
#     "i\\'m looking for the script for the music man."
#   ],
#   "the secret garden": [
#     "find reviews of the book the secret garden.",
#     "find reviews of the various tv and movie adaptations of the secret garden.",
#     "i\\'m looking for biographical notes about frances hodgson burnett.",
#     "find information about the broadway musical the secret garden."
#   ],
#   "map of the united states": [
#     "find us road maps.",
#     "find detailed geographic maps of the united states.",
#     "find political maps of the united states showing the states and their capitals.",
#     "find printable maps of the united states.",
#     "find a black-and-white outline map of the united states such that a child could color."
#   ],
#   "solar panels": [
#     "what kinds of solar panels and photovoltaic cells are there?",
#     "find information about solar panels that i can install on my home.",
#     "find information about nano-technological solar power."
#   ],
#   "alexian brothers hospital": [
#     "go to the alexian brothers health system homepage.",
#     "find information about the alexian brothers lay catholic order.",
#     "find alexian brothers hospitals."
#   ],
#   "indexed annuity": [
#     "what is an indexed annuity? what are their advantages and disadvantages? what kinds of indexed annuities are there?",
#     "where can i buy an indexed annuity? what investment companies offer them?"
#   ],
#   "wilson antenna": [
#     "go to the wilson antenna homepage.",
#     "what kinds of cb antennas does wilson antenna sell?",
#     "what is the best antenna from wilson for a big truck?",
#     "find reviews of wilson antennas."
#   ],
#   "flame designs": [
#     "find free flame design clipart i can use on a website.",
#     "i\\'m looking for good flame tattoo designs.",
#     "find pictures of flames and fire.",
#     "i want to find flame design decals i can put on my car or motorcycle.",
#     "i\\'m looking for flame design stencils."
#   ],
#   "mitchell college": [
#     "find the homepage for mitchell college.",
#     "find the homepage for the athletics department at mitchell college.",
#     "find information on admissions to mitchell college. how do i become a student there?"
#   ],
#   "dog heat": [
#     "what is the effect of excessive heat on dogs?",
#     "what are symptoms of heat stroke and other heat-related illnesses in dogs?",
#     "find information on dogs\\' reproductive cycle. what does it mean when a dog is \\\"in heat\\\"?"
#   ],
#   "horse hooves": [
#     "find information about horses\\' hooves and how to care for them.",
#     "find pictures of horse hooves.",
#     "what are some injuries or diseases of hooves in horses, and how are they treated?",
#     "describe the anatomy of horses\\' feet and hooves.",
#     "find information on shoeing horses and horseshoe problems."
#   ],
#   "avp": [
#     "go to the homepage for the avp, sponsor of professional beach volleyball events.",
#     "find information about pro beach volleyball tournaments and events sponsored by avp.",
#     "find the homepage for avp antivirus software.",
#     "find reviews of avp antivirus software and comparisons to other products.",
#     "find information about the avon products (avp) company.",
#     "find sites devoted to the \\\"alien vs. predator\\\" movie franchise."
#   ],
#   "discovery channel store": [
#     "find the discovery channel store homepage.",
#     "find discovery channel store locations.",
#     "find science toys and products geared towards teaching science to kids sold by discovery channel stores.",
#     "find discovery channel store products based on the animal planet program."
#   ],
#   "president of the united states": [
#     "find the homepage of the president of the united states.",
#     "find information about the current president of the united states, barack obama.",
#     "find a list of past presidents of the united states.",
#     "find historical information about the office of the president of the united states.",
#     "find pictures of past presidents of the united states.",
#     "what is the mailing address for the president of the united states?"
#   ],
#   "iron": [
#     "find information about iron as an essential nutrient.",
#     "what foods contain iron?",
#     "find sites where i can buy iron supplements.",
#     "find information about the element iron (fe).",
#     "find information about iron deficiencies.",
#     "find dealers in irons for clothing."
#   ],
#   "uss yorktown charleston sc": [
#     "find historical information about the uss yorktown aircraft carriers used during world war 2.",
#     "find information about the uss yorktown exhibit at the patriots point museum."
#   ],
#   "ct jobs": [
#     "find sites for finding a job in connecticut.",
#     "take me to the homepage for the connecticut department of labor.",
#     "what kinds of jobs are most common in the state of connecticut?",
#     "find information about filing an claim for unemployment in connecticut."
#   ],
#   "penguins": [
#     "find the homepage of the pittsburgh penguins",
#     "find pittsburgh penguins merchandise such as hockey jerseys.",
#     "find information about penguins.",
#     "find penguin photos.",
#     "find pictures of the penguins from the animated movie, \\\"madagascar\\\"."
#   ],
#   "how to build a fence": [
#     "find information about building a wooden fence.",
#     "find information about building chain-link fences.",
#     "what materials are best for building fences?",
#     "where can i buy materials for building a fence?"
#   ],
#   "kcs": [
#     "find information on kcs energy, inc., and their merger with petrohawk energy corporation."
#   ],
#   "bellevue": [
#     "find information about bellevue, washington.",
#     "find information about bellevue, nebraska.",
#     "find information about bellevue hospital center in new york, ny.",
#     "find the homepage of bellevue university.",
#     "find the homepage of bellevue college, washington.",
#     "find the homepage of bellevue hospital center in new york, ny."
#   ],
#   "worm": [
#     "find information about computer worms, viruses, and spyware.",
#     "find information about worms in nature.",
#     "find information about the conficker worm."
#   ],
#   "texas border patrol": [
#     "find the homepage for supporters of the u.s. border patrol in texas.",
#     "find information on the mission of the u.s. border patrol in texas.",
#     "how do i get a job with the u.s. border patrol in texas?"
#   ],
#   "flushing": [
#     "find information about flushing, a neighborhood in new york city.",
#     "find information about causes of excessive facial flushing.",
#     "why do people blush? what is blushing?",
#     "find a street map of flushing, ny."
#   ],
#   "moths": [
#     "what do moths and butterflies eat?",
#     "find pictures of moths.",
#     "how can i identify different types of moths?",
#     "what do moth eggs look like?",
#     "how do i control clothes moths in my home?"
#   ],
#   "korean language": [
#     "find background information about the korean language.",
#     "find resources on translating korean to other languages.",
#     "find resources on learning and teaching korean.",
#     "find a history of hangul, the korean writing system.",
#     "find a korean/english bilingual dictionary.",
#     "what are some common korean phrases?"
#   ],
#   "income tax return online": [
#     "find a site where i can fill out my federal income tax return online.",
#     "find information about electronically filing (e-filing) my federal income tax return.",
#     "where can i find information online about filing my income taxes?"
#   ],
#   "vldl levels": [
#     "how are vldl levels determined?",
#     "what are good and bad levels of vldl in a cholesterol test?",
#     "what is the difference between ldl, hdl, and vldl?"
#   ],
#   "pvc": [
#     "find information about pvc pipes and fittings.",
#     "what is the material pvc?",
#     "find information about premature ventricular contractions.",
#     "how are premature ventricular contractions treated?"
#   ],
#   "sewing instructions": [
#     "find sewing sites for beginners.",
#     "find instructions for using a sewing machine.",
#     "find downloadable sewing patterns.",
#     "find helpful sewing tips for beginners.",
#     "find materials for teaching sewing to children."
#   ],
#   "air travel information": [
#     "what restrictions are there for checked baggage during air travel?",
#     "what are the rules for liquids in carry-on luggage?",
#     "find the website at the transportation security administration (tsa) that offers air travel tips."
#   ],
#   "to be or not to be that is the question": [
#     "find the text of hamlet\\'s famous \\\"to be or not to be\\\" soliloquy.",
#     "find famous quotes from shakespeare\\'s plays.",
#     "find a critical analysis of hamlet\\'s \\\"to be or not to be\\\" soliloquy."
#   ],
#   "living in india": [
#     "find information about buying real estate in india.",
#     "find information about how people live in india.",
#     "find information for visitors and immigrants about living in india.",
#     "find history about life and culture in india."
#   ],
#   "the sun": [
#     "find information about the sun, the star in our solar system.",
#     "find the homepage for the u.k. newspaper, the sun.",
#     "find the homepage for the baltimore sun newspaper."
#   ],
#   "neil young": [
#     "find albums by neil young to buy.",
#     "find biographical information about neil young.",
#     "find lyrics or sheet music for neil young\\'s songs.",
#     "find a list of neil young tour dates."
#   ],
#   "kiwi": [
#     "find information on kiwi fruit.",
#     "find information on kiwi birds.",
#     "can i grow a kiwi fruit tree?"
#   ],
#   "tornadoes": [
#     "find information about tornadoes, what causes them, and where they occur.",
#     "find videos and pictures of tornadoes.",
#     "what were the deadliest tornadoes in history?",
#     "find information about forecasting tornadoes."
#   ],
#   "raised gardens": [
#     "find plans for building a raised garden bed.",
#     "find a raised garden bed kit.",
#     "what kind of wood should be used to build a raised garden bed?",
#     "find photos of raised garden beds."
#   ],
#   "bobcat": [
#     "find dealers that sell or rent bobcat tractors and construction equipment.",
#     "find information about wild bobcats.",
#     "find attachments for bobcat tractors.",
#     "find the homepage of the bobcat company."
#   ],
#   "dieting": [
#     "find \\\"reasonable\\\" dieting advice, that is not fads or medications but reasonable methods for weight loss.",
#     "find tips and charts for counting calories while dieting.",
#     "find crash diet plans that promise quick weight loss in a short period of time.",
#     "find herbal diet supplements and appetite suppressants.",
#     "find recommendations for dieting and exercising.",
#     "find information on low-carbohydrate diets."
#   ],
#   "voyager": [
#     "find the homepage for the nasa voyager mission.",
#     "find information about the nasa voyager spacecraft and missions.",
#     "find information about the television series, \\\"star trek: voyager\\\"",
#     "find the homepage of the voyager learning programs."
#   ],
#   "appraisals": [
#     "what companies can give an appraisal of my home\\'s value?",
#     "i\\'m looking for companies that appraise jewelry.",
#     "find examples of employee performance appraisals.",
#     "i\\'m looking for web sites that do antique appraisals."
#   ],
#   "keyboard reviews": [
#     "find reviews of computer keyboards.",
#     "find reviews of electronic keyboards and digital pianos.",
#     "what computer keyboards are best for gaming?"
#   ],
#   "afghanistan": [
#     "find information about afghanistan\\'s history, government, religion, and culture.",
#     "find information about the war in afghanistan.",
#     "find maps of afghanistan."
#   ],
#   "joints": [
#     "find information about joints in the human body.",
#     "find an explanation of the different types of joints used in woodworking.",
#     "find information about joint pain and how to treat it."
#   ],
#   "memory": [
#     "find information about human memory.",
#     "find information on various types of computer memory, and how they are different.",
#     "find vendors that sell computer memory upgrades."
#   ],
#   "continental plates": [
#     "find maps of the continental plates.",
#     "find pages that give information on and evidence for continental drift.",
#     "find background information on plate tectonics and the lithosphere."
#   ],
#   "milwaukee journal sentinel": [
#     "find the milwaukee journal sentinel web site.",
#     "find the sports section of the milwaukee journal sentinel.",
#     "find archives of articles from the milwaukee journal sentinel.",
#     "find obituaries and archived obituaries from the milwaukee journal sentinel."
#   ],
#   "bart sf": [
#     "find bart train schedules and fares.",
#     "find maps of the bart system.",
#     "find a site that automatically plans trips on the bart system."
#   ],
#   "who invented music": [
#     "find information on the history and development of music.",
#     "find a history of classical music.",
#     "find information on the history of rock and roll music.",
#     "who invented the radio?"
#   ],
#   "forearm pain": [
#     "what kinds of injuries or conditions can cause forearm pain?",
#     "find pages or sites that describe the anatomy of the forearm.",
#     "what are some exercises recommended for forearm pain?",
#     "are there good home remedies for elbow pain?",
#     "find information about tendinitis in the forearms.",
#     "find information about supports and braces for the forearm to prevent injury or lessen pain."
#   ],
#   "ocd": [
#     "find basic background information on obsessive-compulsive disorder (ocd).",
#     "what are the symptoms of obsessive-compulsive disorder?",
#     "what medications are used for treating ocd?",
#     "find personal stories about living with ocd.",
#     "find information about ocd in children and how to identify it.",
#     "find strategies for parents of children with ocd."
#   ],
#   "used car parts": [
#     "i\\'m looking for online sites that sell car parts.",
#     "i\\'m looking for the car-part.com web site.",
#     "i want to find a salvage or junk yard.",
#     "i\\'m looking for parts for commercial vehicles such as heavy trucks and semis.",
#     "i want to find online sources for napa parts."
#   ],
#   "mgb": [
#     "find information about the mgb sports car.",
#     "find sites for mgb car owners and enthusiasts.",
#     "find information on mini gastric bypass surgery."
#   ],
#   "er tv show": [
#     "find summaries of episodes from the show er.",
#     "find episodes of er i can download or watch online.",
#     "find music that featured on the show er."
#   ],
#   "the wall": [
#     "find information about the pink floyd album, \\\"the wall\\\"",
#     "where can i buy pink floyd\\'s album, \\\"the wall\\\"?",
#     "find information about the vietnam veterans memorial in washington, dc.",
#     "find sites devoted to the vietnam veterans memorial, such as virtual tours and databases of names inscribed on the wall.",
#     "find information about the movie \\\"pink floyd the wall\\\"."
#   ],
#   "raffles": [
#     "find the homepage of raffles hotel in singapore.",
#     "find biographical information about sir stamford raffles.",
#     "find information on organizing a raffle, for example for a charity or school.",
#     "find the homepage of the raffles hotel in dubai.",
#     "find information about car raffles."
#   ],
#   "titan": [
#     "find information on the nissan titan truck.",
#     "find the homepage for titan watches.",
#     "find the homepage for titan motorcycles.",
#     "find information about saturn\\'s moon, titan.",
#     "find the homepage of the tennessee titans."
#   ],
#   "rice": [
#     "find recipes for rice, for example fried rice or rice pudding.",
#     "find the homepage of rice university.",
#     "find biographical information about former secretary of state condoleeza rice.",
#     "what is the nutritional value of white rice?"
#   ],
#   "south africa": [
#     "find pages that give the history of south africa.",
#     "find maps of south africa.",
#     "find pictures of south africa."
#   ],
#   "sat": [
#     "how do i register to take the sat exam?",
#     "find general information about the sats.",
#     "what are typical and good ranges for sat scores? what is the average score?",
#     "find information on test preparation materials and courses for the sat.",
#     "take me to the homepage of the college board, authors of the sat."
#   ],
#   "satellite": [
#     "find background information about man-made satellites.",
#     "find satellite maps and geographic images.",
#     "find providers of satellite television.",
#     "find information about satellite telephones.",
#     "find providers of satellite internet service.",
#     "find providers of satellite radio systems."
#   ]
# }

# %%
def collect_sbert_training_data(history_dict):
    """
    Collects context-question pairs from Qulac history for SBERT fine-tuning.
    - Uses the pre-built history_list to build context.
    - Removes duplicate (context, question) pairs.

    Returns: DataFrame with 'context' and 'question' columns.
    """
    data = []
    for record in history_dict.values():
        query = record["query"]
        history_list = record["history_list"]
        latest_question = record["question"]

        # Convert history_list into formatted context string
        context = query
        for entry in history_list:
            question = entry["question"]
            answer = entry["answer"]

            # Update context for the next round by adding Q/A
            context += f" [Q] {question} [A] {answer}"
        data.append((context, latest_question))
        
    # Convert set to DataFrame
    sbert_training_data = pd.DataFrame(data, columns=["context", "question"])

    # Drop duplicates
    sbert_training_data.drop_duplicates(ignore_index=True, inplace=True)
    
    return sbert_training_data

# %%
training_data = collect_sbert_training_data(history)

# %%
# Save training data to CSV
training_data.to_csv("sbert_training_data.csv", index=False)

# %%
len(training_data)

# %%
training_data[922305:922308]
# Out:
# Empty DataFrame
# Columns: [context, question]
# Index: []

# %%
data = []
    
for record_id, record in history.items():
    history_id = record["history_id"]
    query = record["query"]
    question = record["question"]
    answer = record["answer"]
    history_list = record["history_list"]
    
    # Convert history_list to a formatted string
    formatted_history = " ".join([f"[Q] {h['question']} [A] {h['answer']}" for h in history_list])

    data.append((history_id, query, question, answer, formatted_history))

# Convert list of records into DataFrame
hist_df = pd.DataFrame(data, columns=["history_id", "query", "question", "answer", "history_list"])

# %%
hist_df[2000:2050]
# Out:
#      history_id    query                                           question  \
# 2000       35-5  hoboken  are you looking for information about the hobo...
# 2001       35-6  hoboken  are you looking for information about the hobo...
# 2002       35-1  hoboken                     do you want a hotel in hoboken
# 2003       35-2  hoboken                     do you want a hotel in hoboken
# 2004       35-3  hoboken                     do you want a hotel in hoboken
# 2005       35-4  hoboken                     do you want a hotel in hoboken
# 2006       35-5  hoboken                     do you want a hotel in hoboken
# 2007       35-6  hoboken                     do you want a hotel in hoboken
# 2008       35-1  hoboken                  do you want directions to hoboken
# 2009       35-2  hoboken                  do you want directions to hoboken
# 2010       35-3  hoboken                  do you want directions to hoboken
# 2011       35-4  hoboken                  do you want directions to hoboken
# 2012       35-5  hoboken                  do you want directions to hoboken
# 2013       35-6  hoboken                  do you want directions to hoboken
# 2014       35-1  hoboken  do you want information on the climate of hoboken
# 2015       35-2  hoboken  do you want information on the climate of hoboken
# 2016       35-3  hoboken  do you want information on the climate of hoboken
# 2017       35-4  hoboken  do you want information on the climate of hoboken
# 2018       35-5  hoboken  do you want information on the climate of hoboken
# 2019       35-6  hoboken  do you want information on the climate of hoboken
# 2020       35-1  hoboken               do you want to know where hoboken is
# 2021       35-2  hoboken               do you want to know where hoboken is
# 2022       35-3  hoboken               do you want to know where hoboken is
# 2023       35-4  hoboken               do you want to know where hoboken is
# 2024       35-5  hoboken               do you want to know where hoboken is
# 2025       35-6  hoboken               do you want to know where hoboken is
# 2026       35-1  hoboken   do you want to see points of interest in hoboken
# 2027       35-2  hoboken   do you want to see points of interest in hoboken
# 2028       35-3  hoboken   do you want to see points of interest in hoboken
# 2029       35-4  hoboken   do you want to see points of interest in hoboken
# 2030       35-5  hoboken   do you want to see points of interest in hoboken
# 2031       35-6  hoboken   do you want to see points of interest in hoboken
# 2032       35-1  hoboken                       do you want to visit hoboken
# 2033       35-2  hoboken                       do you want to visit hoboken
# 2034       35-3  hoboken                       do you want to visit hoboken
# 2035       35-4  hoboken                       do you want to visit hoboken
# 2036       35-5  hoboken                       do you want to visit hoboken
# 2037       35-6  hoboken                       do you want to visit hoboken
# 2038       35-1  hoboken      would you like to know the history of hoboken
# 2039       35-2  hoboken      would you like to know the history of hoboken
# 2040       35-3  hoboken      would you like to know the history of hoboken
# 2041       35-4  hoboken      would you like to know the history of hoboken
# 2042       35-5  hoboken      would you like to know the history of hoboken
# 2043       35-6  hoboken      would you like to know the history of hoboken
# 2044       36-1      gps   are you interested in how gps was orginally made
# 2045       36-4      gps   are you interested in how gps was orginally made
# 2046       36-1      gps      are you interested in the accuracy of the gps
# 2047       36-4      gps      are you interested in the accuracy of the gps
# 2048       36-1      gps                are you looking for gps accessories
# 2049       36-4      gps                are you looking for gps accessories
#
#                                                  answer history_list
# 2000  no i am interested in real estate listings in ...
# 2001     no i want to find a streetlevel map of hoboken
# 2002  no a different kind of business establishment ...
# 2003  no i am looking for general information about ...
# 2004         i want to know more about hobokens history
# 2005  no i would like information on bars and nightc...
# 2006                                 no estate listings
# 2007  no i am looking for a walking map of hoboken n...
# 2008   no just give me a listing of hoboken restaurants
# 2009  no im looking for information about the websit...
# 2010                      no i want to know the history
# 2011  no i want to know where the popular bars and n...
# 2012         no i want real estate listings for hoboken
# 2013  what im looking for is related to hoboken but ...
# 2014                     no list restaurants in hoboken
# 2015  no rather i am trying to located the homepage ...
# 2016  no i want information regarding hobokens histo...
# 2017                              no i do not need that
# 2018          no just listings of properties in hoboken
# 2019                            no im looking for a map
# 2020                 no just what restaurants are there
# 2021   no i just need to find the hompeage for the city
# 2022    i want to learn what the history of hobroken is
# 2023  no i would like to know about the citys bars a...
# 2024  no i want to find real estate listings in hoboken
# 2025        i would like a street level map of the city
# 2026    yes i want to see points of interest in hoboken
# 2027                    no i need their web site please
# 2028             yes if they are related to the history
# 2029  i really want to see the night clubs and bars ...
# 2030  i am looking for locations in hoboken but not ...
# 2031  not specifically although they may be included...
# 2032  i would like to know about available restauran...
# 2033     maybe i want to find the homepage for the city
# 2034            no i am interested in the citys history
# 2035  i cant definitively say yes or no to that but ...
# 2036          no i want to look at real estate listings
# 2037                        i cant answer that for sure
# 2038                                                 no
# 2039  no i would like to find the homepage for the c...
# 2040                                        yes i would
# 2041          no just about nightclub and bar locations
# 2042  no i need to a list of the real estate listing...
# 2043                              no i want a map of it
# 2044  no i am looking for personal opinions on gps a...
# 2045  no i want to read reviews of digital cameras w...
# 2046   no i am looking for the reviews of the gps units
# 2047  i am interested in knowing more about digital ...
# 2048  no i want to read reviews of gps units and car...
# 2049  no i am looking for reviews of digital cameras...

# %%
hist_df[hist_df['history_list'].notna()]
# Out:
#          history_id                       query  \
# 0               1-1           obama family tree
# 1               1-2           obama family tree
# 2               1-3           obama family tree
# 3               1-1           obama family tree
# 4               1-2           obama family tree
# ...             ...                         ...
# 922305  200-4-15-17  ontario california airport
# 922306  200-1-16-17  ontario california airport
# 922307  200-2-16-17  ontario california airport
# 922308  200-3-16-17  ontario california airport
# 922309  200-4-16-17  ontario california airport
#
#                                                  question  \
# 0       are you interested in seeing barack obamas family
# 1       are you interested in seeing barack obamas family
# 2       are you interested in seeing barack obamas family
# 3       are you looking for biological information on ...
# 4       are you looking for biological information on ...
# ...                                                   ...
# 922305  would you like to hear nes about ontario calif...
# 922306  would you like to hear nes about ontario calif...
# 922307  would you like to hear nes about ontario calif...
# 922308  would you like to hear nes about ontario calif...
# 922309  would you like to hear nes about ontario calif...
#
#                                                    answer  \
# 0                      yes am interested in obamas family
# 1       no i want to know where obamas parents and gra...
# 2       yes please find me information on barack obama...
# 3       no i need the specific time magazine article t...
# 4       yes specifically information about his parents...
# ...                                                   ...
# 922305                                no just the address
# 922306  no i am seeking flight information for the air...
# 922307  no i am interested in hotels located near the ...
# 922308                                                 no
# 922309                                no just the address
#
#                                              history_list
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...
# 922305  [Q] do you need directions to ontario californ...
# 922306  [Q] would you like to book a flight at ontario...
# 922307  [Q] would you like to book a flight at ontario...
# 922308  [Q] would you like to book a flight at ontario...
# 922309  [Q] would you like to book a flight at ontario...
#
# [922310 rows x 5 columns]

# %%
print(history.keys())

# %%
# Inspect Qulac
data_df = pd.DataFrame.from_dict(data)
# print(f"data:\n{data_df.head()}")
print(f"data cols: {data_df.columns}")
# print(f"data:\n{data_df.iloc[50:70]}\n")
# print(f"data:\n{data_df[data_df['question'] == data_df.iloc[50]['question']]}")
print(f"data:\n{data_df[data_df['topic_type'] == 'ambiguous'].iloc[276]}")
# Out:
# data cols: Index(['topic_id', 'facet_id', 'topic_facet_id', 'topic_facet_question_id',
#        'topic', 'topic_type', 'facet_type', 'topic_desc', 'facet_desc',
#        'question', 'answer'],
#       dtype='object')
# data:
# topic_id                                                                 142
# facet_id                                                                   1
# topic_facet_id                                                         142-1
# topic_facet_question_id                                              142-1-5
# topic                                                     illinois state tax
# topic_type                                                         ambiguous
# facet_type                                                               inf
# topic_desc                 information about the sales tax in Illinois: w...
# facet_desc                 information about the sales tax in Illinois: w...
# question                   do you want to know what the illinois state ta...
# answer                          yes as well as what products it is levied on
# Name: 2356, dtype: object

# %%
b = data_df[100:102]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 b = data_df[100:102]
#
# NameError: name 'data_df' is not defined

# %%
cheap = data_df[data_df['topic'] == 'cheap internet']
# cheap['facet_desc'].unique()
# cheap_facet = cheap[cheap['facet_desc'] == 'What are some low-cost broadband internet providers?']
# cheap_facet['answer'].unique()
# len(cheap_facet)

# %%
cheap[cheap['question'] == "are you wondering who used cheap internet"]
# Out:
#      topic_id  facet_id topic_facet_id topic_facet_question_id  \
# 40         10         1           10-1                 10-1-10
# 55         10         2           10-2                 10-2-10
# 70         10         3           10-3                 10-3-10
# 85         10         5           10-5                 10-5-10
# 100        10         6           10-6                 10-6-10
# 115        10         7           10-7                 10-7-10
#
#               topic topic_type facet_type  \
# 40   cheap internet    faceted        inf
# 55   cheap internet    faceted        inf
# 70   cheap internet    faceted        inf
# 85   cheap internet    faceted        inf
# 100  cheap internet    faceted        inf
# 115  cheap internet    faceted        inf
#
#                                             topic_desc  \
# 40   I\'m looking for cheap (i.e. low-cost) interne...
# 55   I\'m looking for cheap (i.e. low-cost) interne...
# 70   I\'m looking for cheap (i.e. low-cost) interne...
# 85   I\'m looking for cheap (i.e. low-cost) interne...
# 100  I\'m looking for cheap (i.e. low-cost) interne...
# 115  I\'m looking for cheap (i.e. low-cost) interne...
#
#                                             facet_desc  \
# 40   What are some low-cost broadband internet prov...
# 55       Do any internet providers still sell dial-up?
# 70   Who can provide inexpensive digital cable tele...
# 85   Find me some providers of free wireless intern...
# 100                I want to find cheap DSL providers.
# 115  Is there a way to get internet access without ...
#
#                                       question  \
# 40   are you wondering who used cheap internet
# 55   are you wondering who used cheap internet
# 70   are you wondering who used cheap internet
# 85   are you wondering who used cheap internet
# 100  are you wondering who used cheap internet
# 115  are you wondering who used cheap internet
#
#                                                 answer
# 40        no i want to know the lowcost broadband isps
# 55                    no can i still get dialup access
# 70   no i am interested in which companies offer ch...
# 85                no i want providers of free wireless
# 100  no i was wondering who the cheapest dsl provid...
# 115  no i want internet package excluding phone ser...

# %%
def process_qulac_main(data_df):
    """
    Process Qulac main dataset into a dictionary grouped by topic and facet.
    
    {topic:{
        "facets":{
            facet:{
                "questions":{
                    question:[answer list]
                }
            }
        }
    }}
    """
    structured_data = {}

    for _, row in data_df.iterrows():
        topic = row["topic"]
        facet_desc = row["facet_desc"]
        question = row["question"]
        answer = row["answer"]

        if question == "" or answer == "":
            continue

        # Initialise topic if doesn't exist
        if topic not in structured_data:
            structured_data[topic] = {"facets": {}}

        # Initialise facet if doesn't exist
        if facet_desc not in structured_data[topic]["facets"]:
            structured_data[topic]["facets"][facet_desc] = {"questions": {}}

        # Initialise question if doesn't exist
        if question not in structured_data[topic]["facets"][facet_desc]["questions"]:
            structured_data[topic]["facets"][facet_desc]["questions"][question] = []

        # Append answer
        structured_data[topic]["facets"][facet_desc]["questions"][question].append(answer)

    return structured_data

# %%
# Process qulac main dataset into structured dictionary
qulac_structured_dict = process_qulac_main(data_df)

# %%
# View contents of structured dictionary
print(json.dumps(qulac_structured_dict, indent=6))
# Out:
# {
#       "obama family tree": {
#             "facets": {
#                   "Find the TIME magazine photo essay \\\"Barack Obama\\'s Family Tree\\\".": {
#                         "questions": {
#                               "are you interested in seeing barack obamas family": [
#                                     "yes am interested in obamas family"
#                               ],
#                               "would you like to know barack obamas geneology": [
#                                     "yes i want to know who made up his family"
#                               ],
#                               "would you like to know about obamas ancestors": [
#                                     "yes this is what am looking for"
#                               ],
#                               "would you like to know who is currently alive from president obamas family tree": [
#                                     "no find the barack obamas family tree time magazine photo essay"
#                               ],
#                               "are you looking for biological information on his family": [
#                                     "no i need the specific time magazine article titled barack obamas family tree"
#                               ],
#                               "are you referring to the time magazine essay": [
#                                     "yes please locate the photo essay"
#                               ],
#                               "do you want to know more about obamas parents": [
#                                     "yes"
#                               ],
#                               "how many generations would you like me to list from president obamas family tree": [
#                                     "none"
#                               ],
#                               "what would you like to know about obamas heritage": [
#                                     "no i am looking for the time magazine article titled barack obamas family tree"
#                               ],
#                               "which family members of obama are you interested in learning more about": [
#                                     "no i just want to see the barack obamas family tree photo essay on time magazine"
#                               ],
#                               "which specific details would you like to learn about obamas heritage": [
#                                     "im looking for the time magazine photo essay called barack obamas family tree"
#                               ],
#                               "would you like to hear about president obamas family tree": [
#                                     "i would like the barack obama family tree in the time magazine photo essay"
#                               ]
#                         }
#                   },
#                   "Where did Barack Obama\\'s parents and grandparents come from?": {
#                         "questions": {
#                               "are you interested in seeing barack obamas family": [
#                                     "no i want to know where obamas parents and grandparents came from"
#                               ],
#                               "would you like to know barack obamas geneology": [
#                                     "yes i want to know where obamas parents and grandparents came from"
#                               ],
#                               "would you like to know about obamas ancestors": [
#                                     "yes particualarly information about his parents and grandparents"
#                               ],
#                               "would you like to know who is currently alive from president obamas family tree": [
#                                     "no i want to know where his parents and grandparents are from"
#                               ],
#                               "are you looking for biological information on his family": [
#                                     "yes specifically information about his parents and grandparents"
#                               ],
#                               "are you referring to the time magazine essay": [
#                                     "no i need information about where obamas parents and grandparents are from"
#                               ],
#                               "do you want to know more about obamas parents": [
#                                     "no i would like to know more about obamas grand parrents"
#                               ],
#                               "how many generations would you like me to list from president obamas family tree": [
#                                     "two generations obamas parents and grandparents"
#                               ],
#                               "what would you like to know about obamas heritage": [
#                                     "yes i want information on obamas heritage"
#                               ],
#                               "which family members of obama are you interested in learning more about": [
#                                     "i am interested in learning about where obamas parents and grandparents came from"
#                               ],
#                               "which specific details would you like to learn about obamas heritage": [
#                                     "where they were born at"
#                               ],
#                               "would you like to hear about president obamas family tree": [
#                                     "yes but focus on his parents and grandparents"
#                               ]
#                         }
#                   },
#                   "Find biographical information on Barack Obama\\'s mother.": {
#                         "questions": {
#                               "are you interested in seeing barack obamas family": [
#                                     "yes please find me information on barack obamas mother"
#                               ],
#                               "would you like to know barack obamas geneology": [
#                                     "i would like biographical information on his mother"
#                               ],
#                               "would you like to know about obamas ancestors": [
#                                     "yes specifically his mother"
#                               ],
#                               "would you like to know who is currently alive from president obamas family tree": [
#                                     "no i would like baracks mothers biological information"
#                               ],
#                               "are you looking for biological information on his family": [
#                                     "yes i am specifically looking for biographical information about his morther"
#                               ],
#                               "are you referring to the time magazine essay": [
#                                     "no i just want bio information about barack obamas mother"
#                               ],
#                               "do you want to know more about obamas parents": [
#                                     "yes i only want to find the biographical information on barack obamas mother right now"
#                               ],
#                               "how many generations would you like me to list from president obamas family tree": [
#                                     "i dont want his family tree i just want biographical information on his mother"
#                               ],
#                               "what would you like to know about obamas heritage": [
#                                     "i would like to know information about obamas mother"
#                               ],
#                               "which family members of obama are you interested in learning more about": [
#                                     "i would like to learn about his entire family tree"
#                               ],
#                               "which specific details would you like to learn about obamas heritage": [
#                                     "i want to know about obamas mother"
#                               ],
#                               "would you like to hear about president obamas family tree": [
#                                     "i want information on his mother"
#                               ]
#                         }
#                   }
#             }
#       },
#       "cheap internet": {
#             "facets": {
#                   "What are some low-cost broadband internet providers?": {
#                         "questions": {
#                               "are you interested in finding cheap items on the internet": [
#                                     "no i need information about internet providers"
#                               ],
#                               "are you wondering who used cheap internet": [
#                                     "no i want to know the lowcost broadband isps"
#                               ],
#                               "do you already have a phone service": [
#                                     "i dont know"
#                               ],
#                               "how do you know if your internet service is inexpensive": [
#                                     "i would like to know if my internet service is inexpensive"
#                               ],
#                               "or maybe free internet": [
#                                     "not completely free but for as little money as possible"
#                               ],
#                               "what companies have the lowestcost internet service": [
#                                     "i dont know"
#                               ],
#                               "are you interested in lowcost internet providers": [
#                                     "yes i am looking for some examples of lowcost isps"
#                               ],
#                               "are you looking for any bundles or deals": [
#                                     "yes just anything from cheap isps"
#                               ],
#                               "are you looking for information on any specific internet technology": [
#                                     "yes broadband"
#                               ],
#                               "are you looking to buy cheap internet": [
#                                     "yes i want to know who provides lowcost internet"
#                               ],
#                               "are you upset by the quality of your internet service": [
#                                     "no i need lowcost broadband isps"
#                               ],
#                               "are you wondering how to reduce your internet bill": [
#                                     "no im interested in cheap service providers"
#                               ],
#                               "are you wondering where cheap internet is": [
#                                     "i need examples of lowcost internet providers"
#                               ],
#                               "are you wondering which provider has the cheapest internet": [
#                                     "yes i am looking for companies offering lowpriced internet services"
#                               ]
#                         }
#                   },
#                   "Do any internet providers still sell dial-up?": {
#                         "questions": {
#                               "are you interested in finding cheap items on the internet": [
#                                     "yes i would like to no if any isps sell dial up at a low price"
#                               ],
#                               "are you wondering who used cheap internet": [
#                                     "no can i still get dialup access"
#                               ],
#                               "do you already have a phone service": [
#                                     "i just want to know if dial up is still an option"
#                               ],
#                               "how do you know if your internet service is inexpensive": [
#                                     "i dont know"
#                               ],
#                               "or maybe free internet": [
#                                     "no i would like to find an internet provider that sells dialup"
#                               ],
#                               "what companies have the lowestcost internet service": [
#                                     "i am looking for those internet providers that have dialup still"
#                               ],
#                               "are you interested in lowcost internet providers": [
#                                     "yes i am interested if there are any providers who still sell dialup"
#                               ],
#                               "are you looking for any bundles or deals": [
#                                     "no"
#                               ],
#                               "are you looking for information on any specific internet technology": [
#                                     "yes dialup"
#                               ],
#                               "are you looking to buy cheap internet": [
#                                     "yes but more specifically i am wondering if any internet providers still sell dialup"
#                               ],
#                               "are you upset by the quality of your internet service": [
#                                     "no my query is related to type of internet service not quality"
#                               ],
#                               "are you wondering how to reduce your internet bill": [
#                                     "yes specifically through switching to a dial up service"
#                               ],
#                               "are you wondering where cheap internet is": [
#                                     "no i want to know if dialup is still offered"
#                               ],
#                               "are you wondering which provider has the cheapest internet": [
#                                     "no i was wondering if dialup is still a thing any internet providers currently sell"
#                               ]
#                         }
#                   },
#                   "Who can provide inexpensive digital cable television bundled with internet service?": {
#                         "questions": {
#                               "are you interested in finding cheap items on the internet": [
#                                     "no i need cheap internet and tv"
#                               ],
#                               "are you wondering who used cheap internet": [
#                                     "no i am interested in which companies offer cheap internet"
#                               ],
#                               "do you already have a phone service": [
#                                     "yes but which providers bundle cable with internet service"
#                               ],
#                               "how do you know if your internet service is inexpensive": [
#                                     "no who has inexpensive digital cable bundled with internet service"
#                               ],
#                               "or maybe free internet": [
#                                     "i am looking for providers of cheap tv and internet service bundles"
#                               ],
#                               "what companies have the lowestcost internet service": [
#                                     "yes but more than that not just internet service in and of itself"
#                               ],
#                               "are you interested in lowcost internet providers": [
#                                     "yes i am interested"
#                               ],
#                               "are you looking for any bundles or deals": [
#                                     "yes a bundle consisting of digital cable and internet"
#                               ],
#                               "are you looking for information on any specific internet technology": [
#                                     "yes i want inexpensive cable with internet"
#                               ],
#                               "are you looking to buy cheap internet": [
#                                     "yes but i want to know which companies offer the cheapest options for bundled digital cable and internet"
#                               ],
#                               "are you upset by the quality of your internet service": [
#                                     "no i just want providers that bundle cable and internet"
#                               ],
#                               "are you wondering how to reduce your internet bill": [
#                                     "no im wondering who offers cheap digital cable television that is bundled with internet service"
#                               ],
#                               "are you wondering where cheap internet is": [
#                                     "no i want to find cheap internet providers who also offer bundled cable services"
#                               ],
#                               "are you wondering which provider has the cheapest internet": [
#                                     "i would also like inexpensive cable tv bundled with the cheap internet"
#                               ]
#                         }
#                   },
#                   "Find me some providers of free wireless internet access.": {
#                         "questions": {
#                               "are you interested in finding cheap items on the internet": [
#                                     "no im looking for free internet providers"
#                               ],
#                               "are you wondering who used cheap internet": [
#                                     "no i want providers of free wireless"
#                               ],
#                               "do you already have a phone service": [
#                                     "yes i do have phone service"
#                               ],
#                               "how do you know if your internet service is inexpensive": [
#                                     "its affordable compared to the national average"
#                               ],
#                               "or maybe free internet": [
#                                     "yes how can i get free internet"
#                               ],
#                               "what companies have the lowestcost internet service": [
#                                     "i dont know"
#                               ],
#                               "are you interested in lowcost internet providers": [
#                                     "yes i am looking for low cost internet providers"
#                               ],
#                               "are you looking for any bundles or deals": [
#                                     "possibly what providers offer free wireless"
#                               ],
#                               "are you looking for information on any specific internet technology": [
#                                     "i would like to know more about afordable internet"
#                               ],
#                               "are you looking to buy cheap internet": [
#                                     "no i want to find it for free"
#                               ],
#                               "are you upset by the quality of your internet service": [
#                                     "no"
#                               ],
#                               "are you wondering how to reduce your internet bill": [
#                                     "not just to reduce it i want it free"
#                               ],
#                               "are you wondering where cheap internet is": [
#                                     "not just cheap i want to find free wireless providers"
#                               ],
#                               "are you wondering which provider has the cheapest internet": [
#                                     "yes specifically at no cost"
#                               ]
#                         }
#                   },
#                   "I want to find cheap DSL providers.": {
#                         "questions": {
#                               "are you interested in finding cheap items on the internet": [
#                                     "no i am looking for internet service providers"
#                               ],
#                               "are you wondering who used cheap internet": [
#                                     "no i was wondering who the cheapest dsl providers are"
#                               ],
#                               "do you already have a phone service": [
#                                     "that doesnt matter i want to know about cheap providers"
#                               ],
#                               "how do you know if your internet service is inexpensive": [
#                                     "i am looking for cheap dsl providers"
#                               ],
#                               "or maybe free internet": [
#                                     "yes free or low cost"
#                               ],
#                               "what companies have the lowestcost internet service": [
#                                     "yes"
#                               ],
#                               "are you interested in lowcost internet providers": [
#                                     "yes specifically those offering dsl service"
#                               ],
#                               "are you looking for any bundles or deals": [
#                                     "as long it they are tied to cheap dsl providers"
#                               ],
#                               "are you looking for information on any specific internet technology": [
#                                     "yes i want to find inexpensive dsl providers"
#                               ],
#                               "are you looking to buy cheap internet": [
#                                     "yes dsl specifically"
#                               ],
#                               "are you upset by the quality of your internet service": [
#                                     "i am not rather i am trying to find inexpensive dsl providers"
#                               ],
#                               "are you wondering how to reduce your internet bill": [
#                                     "yes i need a list of the companies in my area that have the lowest price for providing internet"
#                               ],
#                               "are you wondering where cheap internet is": [
#                                     "i want cheap dsl providers"
#                               ],
#                               "are you wondering which provider has the cheapest internet": [
#                                     "yes"
#                               ]
#                         }
#                   },
#                   "Is there a way to get internet access without phone service?": {
#                         "questions": {
#                               "are you interested in finding cheap items on the internet": [
#                                     "i want internet without phone service"
#                               ],
#                               "are you wondering who used cheap internet": [
#                                     "no i want internet package excluding phone service"
#                               ],
#                               "do you already have a phone service": [
#                                     "probably not but i am unable to answer for sure"
#                               ],
#                               "how do you know if your internet service is inexpensive": [
#                                     "no i want to know if there is a way of getting internet without having phone service"
#                               ],
#                               "or maybe free internet": [
#                                     "no that is not what i am asking"
#                               ],
#                               "what companies have the lowestcost internet service": [
#                                     "no i want to know who offers internet without phone services"
#                               ],
#                               "are you interested in lowcost internet providers": [
#                                     "no id like to know if internet access is available without phone service"
#                               ],
#                               "are you looking for any bundles or deals": [
#                                     "no i just want internet"
#                               ],
#                               "are you looking for information on any specific internet technology": [
#                                     "yes specifically related to accessing the internet"
#                               ],
#                               "are you looking to buy cheap internet": [
#                                     "no"
#                               ],
#                               "are you upset by the quality of your internet service": [
#                                     "no i want to be able to use the internet without phone service"
#                               ],
#                               "are you wondering how to reduce your internet bill": [
#                                     "no"
#                               ],
#                               "are you wondering where cheap internet is": [
#                                     "no"
#                               ],
#                               "are you wondering which provider has the cheapest internet": [
#                                     "no i would like to know if theres a way to get internet access without phone service"
#                               ]
#                         }
#                   }
#             }
#       },
#       "ritz carlton lake las vegas": {
#             "facets": {
#                   "Find information about the Ritz Carlton resort at Lake Las Vegas.": {
#                         "questions": {
#                               "are you looking for a specific web site": [
#                                     "yes for the ritz carlton resort at lake las vegas"
#                               ],
#                               "would you like the history of ritz carlton lake las vegas": [
#                                     "where can i find the history of the ritz carton lake in las vegas "
#                               ],
#                               "would you like the location of the ritz carlton lake las vegas": [
#                                     "yes along with other information"
#                               ],
#                               "would you like to know the capacity of ritz carlton lake las vegas": [
#                                     "yes and other information"
#                               ],
#                               "would you like to know where ritz carlton lake las vegas is on a map": [
#                                     "no i want to know more about the ritz carlton lake las vegas resort"
#                               ],
#                               "would you like to read some reviews of the ritz carlton lake las vegas": [
#                                     "no i just need information on the ritz carlton"
#                               ],
#                               "are you looking for any specific games to play there": [
#                                     "no i just want general information about the resort"
#                               ],
#                               "are you looking for directions to the ritz carlton in las vegas": [
#                                     "possibly but only the one that has a lake"
#                               ],
#                               "are you looking for the closest lake to the ritz carlton in las vegas": [
#                                     "no i am trying to find information about the ritz carlton at lake las vegas"
#                               ],
#                               "are you wanting a room at the ritz carlton in las vegas": [
#                                     "yes"
#                               ],
#                               "are you wanting the rates for the ritz carlton in las vegas": [
#                                     "yes"
#                               ],
#                               "are you wondering where the ritz carlton in las vegas is located": [
#                                     "yes but also tell me general information about it"
#                               ],
#                               "do you need a reservation at the ritz carlton in las vegas": [
#                                     "just information"
#                               ],
#                               "do you want historical information on the ritz carlton lake las vegas": [
#                                     "i dont know i think i am more interested in current information"
#                               ]
#                         }
#                   },
#                   "Find a site where I can determine room price and availability.": {
#                         "questions": {
#                               "are you looking for a specific web site": [
#                                     "i am looking for a site that gives me booking prices for rooms"
#                               ],
#                               "would you like the history of ritz carlton lake las vegas": [
#                                     "no i want a webpage i can use to book a room"
#                               ],
#                               "would you like the location of the ritz carlton lake las vegas": [
#                                     "i would like a website or app that compares prices and shows availability"
#                               ],
#                               "would you like to know the capacity of ritz carlton lake las vegas": [
#                                     "no i need the site where i can determine room price and availability"
#                               ],
#                               "would you like to know where ritz carlton lake las vegas is on a map": [
#                                     "no i want to know room price and availability"
#                               ],
#                               "would you like to read some reviews of the ritz carlton lake las vegas": [
#                                     "no"
#                               ],
#                               "are you looking for any specific games to play there": [
#                                     "no"
#                               ],
#                               "are you looking for directions to the ritz carlton in las vegas": [
#                                     "no i am looking for room price and availability at ritz carlton in las vegas"
#                               ],
#                               "are you looking for the closest lake to the ritz carlton in las vegas": [
#                                     "i would like to look at pricing and availbility for a room in las vegas"
#                               ],
#                               "are you wanting a room at the ritz carlton in las vegas": [
#                                     "yes i am looking for information on the room price"
#                               ],
#                               "are you wanting the rates for the ritz carlton in las vegas": [
#                                     "yes i need room prices and availability"
#                               ],
#                               "are you wondering where the ritz carlton in las vegas is located": [
#                                     "no i need the price and availability"
#                               ],
#                               "do you need a reservation at the ritz carlton in las vegas": [
#                                     "i dont know"
#                               ],
#                               "do you want historical information on the ritz carlton lake las vegas": [
#                                     "i just need to know how much a room is"
#                               ]
#                         }
#                   },
#                   "Find directions to the Ritz Carlton Lake Las Vegas.": {
#                         "questions": {
#                               "are you looking for a specific web site": [
#                                     "yes the ritz carlton located in lake las vegas for directions"
#                               ],
#                               "would you like the history of ritz carlton lake las vegas": [
#                                     "no i need directions"
#                               ],
#                               "would you like the location of the ritz carlton lake las vegas": [
#                                     "yes i would like the location of the ritz carlton lake las vegas"
#                               ],
#                               "would you like to know the capacity of ritz carlton lake las vegas": [
#                                     "no i would like directions to the ritz calton lake las vegas"
#                               ],
#                               "would you like to know where ritz carlton lake las vegas is on a map": [
#                                     "yes i need directions to the ritz carlton lake las vegas"
#                               ],
#                               "would you like to read some reviews of the ritz carlton lake las vegas": [
#                                     "no i need directions to the ritz carlton in lake las vegas"
#                               ],
#                               "are you looking for any specific games to play there": [
#                                     "no i am looking for directions to the ritz carlton in las vegas"
#                               ],
#                               "are you looking for directions to the ritz carlton in las vegas": [
#                                     "i need directions to ritz carlton lake"
#                               ],
#                               "are you looking for the closest lake to the ritz carlton in las vegas": [
#                                     "no i am looking for directions to the ritz carlton lake las vegas"
#                               ],
#                               "are you wanting a room at the ritz carlton in las vegas": [
#                                     "no i just want directions"
#                               ],
#                               "are you wanting the rates for the ritz carlton in las vegas": [
#                                     "no just directions"
#                               ],
#                               "are you wondering where the ritz carlton in las vegas is located": [
#                                     "yes i need directions"
#                               ],
#                               "do you need a reservation at the ritz carlton in las vegas": [
#                                     "only need the directions"
#                               ],
#                               "do you want historical information on the ritz carlton lake las vegas": [
#                                     "no i want to know how to get there"
#                               ]
#                         }
#                   },
#                   "Find reviews of the Ritz Carlton Lake Las Vegas.": {
#                         "questions": {
#                               "are you looking for a specific web site": [
#                                     "i need a website with reviews for the ritz carlton lake"
#                               ],
#                               "would you like the history of ritz carlton lake las vegas": [
#                                     "no"
#                               ],
#                               "would you like the location of the ritz carlton lake las vegas": [
#                                     "no"
#                               ],
#                               "would you like to know the capacity of ritz carlton lake las vegas": [
#                                     "no i want to get reviews of the ritz carlton lake las vegas"
#                               ],
#                               "would you like to know where ritz carlton lake las vegas is on a map": [
#                                     "no i am looking for reviews"
#                               ],
#                               "would you like to read some reviews of the ritz carlton lake las vegas": [
#                                     "yes id like to read those reviews"
#                               ],
#                               "are you looking for any specific games to play there": [
#                                     "no i am trying to find reviews for the ritz carlton"
#                               ],
#                               "are you looking for directions to the ritz carlton in las vegas": [
#                                     "no i am looking for reviews"
#                               ],
#                               "are you looking for the closest lake to the ritz carlton in las vegas": [
#                                     "no i am wanting to know the reviews of the ritz carlton lake las vegas"
#                               ],
#                               "are you wanting a room at the ritz carlton in las vegas": [
#                                     "no i am looking for reviews of the hotel on lake las vegas"
#                               ],
#                               "are you wanting the rates for the ritz carlton in las vegas": [
#                                     "no i want reviews"
#                               ],
#                               "are you wondering where the ritz carlton in las vegas is located": [
#                                     "no i want the reviews for it"
#                               ],
#                               "do you need a reservation at the ritz carlton in las vegas": [
#                                     "no i am looking for reviews of the ritz carlton lake las vegas"
#                               ],
#                               "do you want historical information on the ritz carlton lake las vegas": [
#                                     "no i am looking for reviews of the hotel"
#                               ]
#                         }
#                   }
#             }
#       },
#       "fickle creek farm": {
#             "facets": {
#                   "Find general information about Fickle Creek Farm in North Carolina": {
#                         "questions": {
#                               "are you going to purchase anything there": [
#                                     "i dont know yet i just want general info about fickle creek farm"
#                               ],
#                               "are you looking for a place which sales products from fickle creek farm": [
#                                     "just general information about the farm"
#                               ],
#                               "are you looking for information about staying at fickle creek farm": [
#                                     "no i am looking for more general information"
#                               ],
#                               "are you looking for specific information regarding fickle creek farm": [
#                                     "im looking for general information"
#                               ],
#                               "do you want the history of fickle creek farm": [
#                                     "yes i would like the history of fickle creek farm"
#                               ],
#                               "do you want to know the animal population at fickle creek farm": [
#                                     "yes along with other general information"
#                               ],
#                               "do you want to know the location of fickle creek farm": [
#                                     "yes along with other general information"
#                               ],
#                               "would you like to know where fickle creek farm is on a map": [
#                                     "i just need general information about fickle creek"
#                               ]
#                         }
#                   },
#                   "Where is Fickle Creek Farm, and how can I go there?": {
#                         "questions": {
#                               "are you going to purchase anything there": [
#                                     "i am not sure"
#                               ],
#                               "are you looking for a place which sales products from fickle creek farm": [
#                                     "no i want the physical address of fickle creek farm"
#                               ],
#                               "are you looking for information about staying at fickle creek farm": [
#                                     "no only its location and travel directions"
#                               ],
#                               "are you looking for specific information regarding fickle creek farm": [
#                                     "yes i am looking for its location and directions on how to get there"
#                               ],
#                               "do you want the history of fickle creek farm": [
#                                     "no i want to know where fickle creek farm is and how i get there"
#                               ],
#                               "do you want to know the animal population at fickle creek farm": [
#                                     "no i need to know how to get there"
#                               ],
#                               "do you want to know the location of fickle creek farm": [
#                                     "i would like to know where fickle creek farm is and also hoe to ge there"
#                               ],
#                               "would you like to know where fickle creek farm is on a map": [
#                                     "yes and i also need directions on how to get there"
#                               ]
#                         }
#                   },
#                   "What products do they grow and/or raise there?": {
#                         "questions": {
#                               "are you going to purchase anything there": [
#                                     "no i just need to know what food is grown or raised on the farms of fickle creek farm"
#                               ],
#                               "are you looking for a place which sales products from fickle creek farm": [
#                                     "no i am interested in the type of products they grow or raise there"
#                               ],
#                               "are you looking for information about staying at fickle creek farm": [
#                                     "no"
#                               ],
#                               "are you looking for specific information regarding fickle creek farm": [
#                                     "yes what products do they grow there"
#                               ],
#                               "do you want the history of fickle creek farm": [
#                                     "no i want to know what products they grow and raise at fickle creek farm"
#                               ],
#                               "do you want to know the animal population at fickle creek farm": [
#                                     "no i want to know what products they grow or raise there"
#                               ],
#                               "do you want to know the location of fickle creek farm": [
#                                     "no i want to know products that they grow or raise there"
#                               ],
#                               "would you like to know where fickle creek farm is on a map": [
#                                     "i would like to know what the make"
#                               ]
#                         }
#                   },
#                   "Where can I buy products that come from Fickle Creek Farm?": {
#                         "questions": {
#                               "are you going to purchase anything there": [
#                                     "i dont know i would like to see what they have first"
#                               ],
#                               "are you looking for a place which sales products from fickle creek farm": [
#                                     "yes thats what i want"
#                               ],
#                               "are you looking for information about staying at fickle creek farm": [
#                                     "i would like to by produce from fickle creek farm"
#                               ],
#                               "are you looking for specific information regarding fickle creek farm": [
#                                     "yes where to buy thier products"
#                               ],
#                               "do you want the history of fickle creek farm": [
#                                     "i want to buy something from them"
#                               ],
#                               "do you want to know the animal population at fickle creek farm": [
#                                     "no i want to know where to buy their products"
#                               ],
#                               "do you want to know the location of fickle creek farm": [
#                                     "no i want ot find out where can i purchase fickle creek farm products"
#                               ],
#                               "would you like to know where fickle creek farm is on a map": [
#                                     "no i would like to know where i can buy products from fickle creek farm not where it is"
#                               ]
#                         }
#                   },
#                   "Find information about staying at the bed and breakfast at Fickle Creek Farm.": {
#                         "questions": {
#                               "are you going to purchase anything there": [
#                                     "not sure i just need information about staying there"
#                               ],
#                               "are you looking for a place which sales products from fickle creek farm": [
#                                     "no i am looking for info on the bed and breakfast at fickle creek farms"
#                               ],
#                               "are you looking for information about staying at fickle creek farm": [
#                                     "yes i am looking for information about staying at fickle creek farm"
#                               ],
#                               "are you looking for specific information regarding fickle creek farm": [
#                                     "yes i want information about staying there"
#                               ],
#                               "do you want the history of fickle creek farm": [
#                                     "no i need information about its bed and breakfast"
#                               ],
#                               "do you want to know the animal population at fickle creek farm": [
#                                     "no i would like to know about staying at the bed and breakfast at fickle creek farm"
#                               ],
#                               "do you want to know the location of fickle creek farm": [
# ...
#                         "questions": {
#                               "are you inquiring about satellite tv": [
#                                     "no i want to find satelite maps and geographic images"
#                               ],
#                               "do you want to know about a satellite receivers or dishes": [
#                                     "no"
#                               ],
#                               "do you want to know about natural or artificial satellites": [
#                                     "artificial but i just need to see maps and geographic images from them"
#                               ],
#                               "do you want to know more about the technology behind satellites": [
#                                     "no i just want to find satellite maps and geographic images"
#                               ],
#                               "what kind of satellite are you looking for": [
#                                     "just maps"
#                               ],
#                               "would you like the definition of the word satellite": [
#                                     "no i would like images from them"
#                               ],
#                               "would you like to know more about satellite tv history": [
#                                     "no find me satellite maps and images"
#                               ],
#                               "are you interested in learning more about satellite phones or radio": [
#                                     "no i want to see images that are satellite and geographic"
#                               ],
#                               "are you looking for a company which provides internet services": [
#                                     "no i am looking for satellite maps"
#                               ],
#                               "are you looking for a specific kind of maps and images": [
#                                     "id like to see maps and geographic images"
#                               ],
#                               "are you looking for history of the satellite radio systems": [
#                                     "no"
#                               ],
#                               "are you referring to satellite imagery on google maps": [
#                                     "yes that would suffice"
#                               ],
#                               "are you referring to the company called satellite industries inc ": [
#                                     "no i am not i want to see satellite maos and geographic images"
#                               ],
#                               "are you talking about a spacecraft or a song": [
#                                     "i am talking about a spacecraft"
#                               ],
#                               "do you want to figure out the benefits of satellite tv over cable tv": [
#                                     "no i am looking for satellite maps and geographic images"
#                               ]
#                         }
#                   },
#                   "Find providers of satellite television.": {
#                         "questions": {
#                               "are you inquiring about satellite tv": [
#                                     "yes i would like providers that offer satellite tv"
#                               ],
#                               "do you want to know about a satellite receivers or dishes": [
#                                     "both"
#                               ],
#                               "do you want to know about natural or artificial satellites": [
#                                     "no i want satellite television"
#                               ],
#                               "do you want to know more about the technology behind satellites": [
#                                     "no i want to find satallite tv providers"
#                               ],
#                               "what kind of satellite are you looking for": [
#                                     "im not sure im looking for a satellite provider"
#                               ],
#                               "would you like the definition of the word satellite": [
#                                     "n i want info on satellite service providers"
#                               ],
#                               "would you like to know more about satellite tv history": [
#                                     "no i need to find satellite tv providers"
#                               ],
#                               "are you interested in learning more about satellite phones or radio": [
#                                     "no i need satellite tv providers"
#                               ],
#                               "are you looking for a company which provides internet services": [
#                                     "looking for satellite tv providers in my area"
#                               ],
#                               "are you looking for a specific kind of maps and images": [
#                                     "no this is not related to my search"
#                               ],
#                               "are you looking for history of the satellite radio systems": [
#                                     "no i am looking for satellite tv providers"
#                               ],
#                               "are you referring to satellite imagery on google maps": [
#                                     "no im looking for companies that provide satellite television"
#                               ],
#                               "are you referring to the company called satellite industries inc ": [
#                                     "no i am looking for companies that provide satellite service"
#                               ],
#                               "are you talking about a spacecraft or a song": [
#                                     "no i am interested in the type of satellite that is offered for television"
#                               ],
#                               "do you want to figure out the benefits of satellite tv over cable tv": [
#                                     "no i wan to find satellite television providers"
#                               ]
#                         }
#                   },
#                   "Find information about satellite telephones.": {
#                         "questions": {
#                               "are you inquiring about satellite tv": [
#                                     "no i need info on satellite tv"
#                               ],
#                               "do you want to know about a satellite receivers or dishes": [
#                                     "no id like to know about satellite telephones"
#                               ],
#                               "do you want to know about natural or artificial satellites": [
#                                     "no i would like information about satellite phones"
#                               ],
#                               "do you want to know more about the technology behind satellites": [
#                                     "no im looking for information on satellite telephones"
#                               ],
#                               "what kind of satellite are you looking for": [
#                                     "i want to find satellite telephons"
#                               ],
#                               "would you like the definition of the word satellite": [
#                                     "i want information on satellite phones"
#                               ],
#                               "would you like to know more about satellite tv history": [
#                                     "no"
#                               ],
#                               "are you interested in learning more about satellite phones or radio": [
#                                     "satellite phones"
#                               ],
#                               "are you looking for a company which provides internet services": [
#                                     "no i want to know about satellite telephones"
#                               ],
#                               "are you looking for a specific kind of maps and images": [
#                                     "no i am looking for satellite telephone info"
#                               ],
#                               "are you looking for history of the satellite radio systems": [
#                                     "no i need information on satellite telephones"
#                               ],
#                               "are you referring to satellite imagery on google maps": [
#                                     "no i am referring to satellite telephone companies"
#                               ],
#                               "are you referring to the company called satellite industries inc ": [
#                                     "no im referring to satellite telephones"
#                               ],
#                               "are you talking about a spacecraft or a song": [
#                                     "im talking about satellite telephones"
#                               ],
#                               "do you want to figure out the benefits of satellite tv over cable tv": [
#                                     "no i want to know about satellite phones"
#                               ]
#                         }
#                   },
#                   "Find providers of satellite internet service.": {
#                         "questions": {
#                               "are you inquiring about satellite tv": [
#                                     "yes exactly"
#                               ],
#                               "do you want to know about a satellite receivers or dishes": [
#                                     "no i want to find the providers"
#                               ],
#                               "do you want to know about natural or artificial satellites": [
#                                     "satellite internet"
#                               ],
#                               "do you want to know more about the technology behind satellites": [
#                                     "no just about available service providers"
#                               ],
#                               "what kind of satellite are you looking for": [
#                                     "im not im looking for service providers"
#                               ],
#                               "would you like the definition of the word satellite": [
#                                     "an artificial body placed in orbit around the earth or moon or another planet in order to collect information or for communition"
#                               ],
#                               "would you like to know more about satellite tv history": [
#                                     "no just show me some current providers"
#                               ],
#                               "are you interested in learning more about satellite phones or radio": [
#                                     "yes"
#                               ],
#                               "are you looking for a company which provides internet services": [
#                                     "yes i am looking for satellite internet providers"
#                               ],
#                               "are you looking for a specific kind of maps and images": [
#                                     "no"
#                               ],
#                               "are you looking for history of the satellite radio systems": [
#                                     "no i am looking for satellite radio providers"
#                               ],
#                               "are you referring to satellite imagery on google maps": [
#                                     "no i am looking for stelitte internet service"
#                               ],
#                               "are you referring to the company called satellite industries inc ": [
#                                     "no i want providers of satellite internet service"
#                               ],
#                               "are you talking about a spacecraft or a song": [
#                                     "no i need satellite internet providers"
#                               ],
#                               "do you want to figure out the benefits of satellite tv over cable tv": [
#                                     "no i need satellite internet providers"
#                               ]
#                         }
#                   },
#                   "Find providers of satellite radio systems.": {
#                         "questions": {
#                               "are you inquiring about satellite tv": [
#                                     "no im not interested in tv"
#                               ],
#                               "do you want to know about a satellite receivers or dishes": [
#                                     "not really either im looking for satellite radio services"
#                               ],
#                               "do you want to know about natural or artificial satellites": [
#                                     "neither i am looking for satellite radio providers"
#                               ],
#                               "do you want to know more about the technology behind satellites": [
#                                     "no i want providers of satellite radio systems"
#                               ],
#                               "what kind of satellite are you looking for": [
#                                     "radio systems"
#                               ],
#                               "would you like the definition of the word satellite": [
#                                     "no i want to know more about satellite radio system providers"
#                               ],
#                               "would you like to know more about satellite tv history": [
#                                     "no show me satellite radio system providers"
#                               ],
#                               "are you interested in learning more about satellite phones or radio": [
#                                     "no i am looking for providers of satellite radio systems"
#                               ],
#                               "are you looking for a company which provides internet services": [
#                                     "no"
#                               ],
#                               "are you looking for a specific kind of maps and images": [
#                                     "no i am just looking for providers of satellite radio systems at this time"
#                               ],
#                               "are you looking for history of the satellite radio systems": [
#                                     "no providers"
#                               ],
#                               "are you referring to satellite imagery on google maps": [
#                                     "no i am referring to satellite radio companies"
#                               ],
#                               "are you referring to the company called satellite industries inc ": [
#                                     "no i want to find providers of satellite radios systems"
#                               ],
#                               "are you talking about a spacecraft or a song": [
#                                     "neither i want satellite radio subscription services"
#                               ],
#                               "do you want to figure out the benefits of satellite tv over cable tv": [
#                                     "no i want to know what providers offer satellite radios"
#                               ]
#                         }
#                   }
#             }
#       }
# }

# %%
a = data_df[39:42]
b = data_df[100:102]
b
# con = pd.concat([a,b])

# print(con)

# %%
# Inspect history
# <topic/query_id>-<facet_id>-*<positional_question_variant>-<instance(seems to always be 1)>
for i, (key, value) in enumerate(history.items()):
    if not re.search("^18-\d-1-", key):
        continue
    print(f"record id: {key}")
    for k, v in value.items():
        print(f"{k}: {v}")

    print()

# %%
i = 0
for record in history.values():
    if i > 5:
        break
    print(record)
    i += 1
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# {'history_id': '200-2-3-8', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just tell me which hotels are the closest to the airport', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'yes the ontario canada airport'}, {'question': 'what ammendities are you looking for in your airport', 'answer': 'i want to know what hotels are near'}]}
# {'history_id': '200-3-3-8', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just what they offer', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'no the one in california'}, {'question': 'what ammendities are you looking for in your airport', 'answer': 'i want informaion on the ontario ca airport ammendities'}]}
# {'history_id': '200-4-3-8', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'yes', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'no i need the street address of the ontario airport'}, {'question': 'what ammendities are you looking for in your airport', 'answer': 'none i just need ontario cas airport address'}]}
# {'history_id': '200-1-3-9', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no i need flight information for the airport', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'yes i am interested in getting information about flights from ontario canada airport'}, {'question': 'would you like directions from your location', 'answer': 'would you like directions from your location'}]}
# {'history_id': '200-2-3-9', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just tell me which hotels are the closest to the airport', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'yes the ontario canada airport'}, {'question': 'would you like directions from your location', 'answer': 'no i just need the hotels near the airport in ontario ca'}]}
# {'history_id': '200-3-3-9', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just what they offer', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'no the one in california'}, {'question': 'would you like directions from your location', 'answer': 'no i would l like to know what services are offiered at the ontairo ca airport'}]}
# {'history_id': '200-4-3-9', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'yes', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'no i need the street address of the ontario airport'}, {'question': 'would you like directions from your location', 'answer': 'yes please give me directions to the dmv'}]}
# {'history_id': '200-1-3-10', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no i need flight information for the airport', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'yes i am interested in getting information about flights from ontario canada airport'}, {'question': 'would you like to book a hotel there', 'answer': 'im looking for flight information for the ontario ca airport'}]}
# {'history_id': '200-2-3-10', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just tell me which hotels are the closest to the airport', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'yes the ontario canada airport'}, {'question': 'would you like to book a hotel there', 'answer': 'i would like to know the hotels near there'}]}
# {'history_id': '200-3-3-10', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just what they offer', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'no the one in california'}, {'question': 'would you like to book a hotel there', 'answer': 'no i would like to know what services are offered a the ontariaca airport'}]}
# {'history_id': '200-4-3-10', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'yes', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'no i need the street address of the ontario airport'}, {'question': 'would you like to book a hotel there', 'answer': 'no thanks i would like the address of the place only'}]}
# {'history_id': '200-1-3-11', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no i need flight information for the airport', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'yes i am interested in getting information about flights from ontario canada airport'}, {'question': 'would you like to buy tickets to california', 'answer': 'yes'}]}
# {'history_id': '200-2-3-11', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just tell me which hotels are the closest to the airport', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'yes the ontario canada airport'}, {'question': 'would you like to buy tickets to california', 'answer': 'no i need to know which hotels are in the area of ontario ca airport'}]}
# {'history_id': '200-3-3-11', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just what they offer', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'no the one in california'}, {'question': 'would you like to buy tickets to california', 'answer': 'no i want to know the facilities and services at ontario california airport'}]}
# {'history_id': '200-4-3-11', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'yes', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'no i need the street address of the ontario airport'}, {'question': 'would you like to buy tickets to california', 'answer': 'no'}]}
# {'history_id': '200-1-3-12', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no i need flight information for the airport', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'yes i am interested in getting information about flights from ontario canada airport'}, {'question': 'would you like to know more about ontarioca airport services', 'answer': 'if it contains flight info'}]}
# {'history_id': '200-2-3-12', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just tell me which hotels are the closest to the airport', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'yes the ontario canada airport'}, {'question': 'would you like to know more about ontarioca airport services', 'answer': 'no want to know about hotels near the airport'}]}
# {'history_id': '200-3-3-12', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just what they offer', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'no the one in california'}, {'question': 'would you like to know more about ontarioca airport services', 'answer': 'yes what type of services do they offer there'}]}
# {'history_id': '200-4-3-12', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'yes', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'no i need the street address of the ontario airport'}, {'question': 'would you like to know more about ontarioca airport services', 'answer': 'no i need to know the exact address of where the ontario ca airport'}]}
# {'history_id': '200-1-3-13', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no i need flight information for the airport', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'yes i am interested in getting information about flights from ontario canada airport'}, {'question': 'would you like to know more about arrivals or departures', 'answer': 'yes that would be perfect'}]}
# {'history_id': '200-2-3-13', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just tell me which hotels are the closest to the airport', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'yes the ontario canada airport'}, {'question': 'would you like to know more about arrivals or departures', 'answer': 'no'}]}
# {'history_id': '200-3-3-13', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just what they offer', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'no the one in california'}, {'question': 'would you like to know more about arrivals or departures', 'answer': 'no i am not intested in fligjt data m'}]}
# {'history_id': '200-4-3-13', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'yes', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'no i need the street address of the ontario airport'}, {'question': 'would you like to know more about arrivals or departures', 'answer': 'no just tell me the address'}]}
# {'history_id': '200-1-3-14', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no i need flight information for the airport', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'yes i am interested in getting information about flights from ontario canada airport'}, {'question': 'are you interested in visiting ontario california airport', 'answer': 'yes i need flight information'}]}
# {'history_id': '200-2-3-14', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just tell me which hotels are the closest to the airport', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'yes the ontario canada airport'}, {'question': 'are you interested in visiting ontario california airport', 'answer': 'no i want hotels close to the airport'}]}
# {'history_id': '200-3-3-14', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just what they offer', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'no the one in california'}, {'question': 'are you interested in visiting ontario california airport', 'answer': 'maybe'}]}
# {'history_id': '200-4-3-14', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'yes', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'no i need the street address of the ontario airport'}, {'question': 'are you interested in visiting ontario california airport', 'answer': 'the airport can be found at 2500 east airport drive'}]}
# {'history_id': '200-1-3-16', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no i need flight information for the airport', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'yes i am interested in getting information about flights from ontario canada airport'}, {'question': 'would you like to book a flight at ontario california airport', 'answer': 'no i just need info'}]}
# {'history_id': '200-2-3-16', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just tell me which hotels are the closest to the airport', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'yes the ontario canada airport'}, {'question': 'would you like to book a flight at ontario california airport', 'answer': 'no'}]}
# {'history_id': '200-3-3-16', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just what they offer', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'no the one in california'}, {'question': 'would you like to book a flight at ontario california airport', 'answer': 'no i want to know about their services and facilities'}]}
# {'history_id': '200-4-3-16', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'yes', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'no i need the street address of the ontario airport'}, {'question': 'would you like to book a flight at ontario california airport', 'answer': 'no i just need the address'}]}
# {'history_id': '200-1-3-17', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no i need flight information for the airport', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'yes i am interested in getting information about flights from ontario canada airport'}, {'question': 'would you like to hear departure times for ontario california airport', 'answer': 'no i need flight information'}]}
# {'history_id': '200-2-3-17', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just tell me which hotels are the closest to the airport', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'yes the ontario canada airport'}, {'question': 'would you like to hear departure times for ontario california airport', 'answer': 'i need to find a hotel near ontario airport in california'}]}
# {'history_id': '200-3-3-17', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just what they offer', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'no the one in california'}, {'question': 'would you like to hear departure times for ontario california airport', 'answer': 'no im looking for services available'}]}
# {'history_id': '200-4-3-17', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'yes', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'no i need the street address of the ontario airport'}, {'question': 'would you like to hear departure times for ontario california airport', 'answer': 'i just need the ontario ca airports address'}]}
# {'history_id': '200-1-3-18', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no i need flight information for the airport', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'yes i am interested in getting information about flights from ontario canada airport'}, {'question': 'would you like to hear nes about ontario california airport', 'answer': 'no i am seeking flight information for the airport in ontario canada'}]}
# {'history_id': '200-2-3-18', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just tell me which hotels are the closest to the airport', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'yes the ontario canada airport'}, {'question': 'would you like to hear nes about ontario california airport', 'answer': 'no i am interested in hotels located near the airport in ontario ca'}]}
# {'history_id': '200-3-3-18', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just what they offer', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'no the one in california'}, {'question': 'would you like to hear nes about ontario california airport', 'answer': 'no'}]}
# {'history_id': '200-4-3-18', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'yes', 'history_list': [{'question': 'do you mean an airport in canada', 'answer': 'no i need the street address of the ontario airport'}, {'question': 'would you like to hear nes about ontario california airport', 'answer': 'no just the address'}]}
# {'history_id': '200-1-4-5', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no i need flight information for the airport', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'no i am looking for flight information for the airport'}, {'question': 'do you need to make a booking are you travelling alone', 'answer': 'i would like to find flight information'}]}
# {'history_id': '200-2-4-5', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just tell me which hotels are the closest to the airport', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'a map would help yes'}, {'question': 'do you need to make a booking are you travelling alone', 'answer': 'i need ontario hotel info'}]}
# {'history_id': '200-3-4-5', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just what they offer', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'no i am looking for the service and facilites offered by the ontario canada airport'}, {'question': 'do you need to make a booking are you travelling alone', 'answer': 'i need facility information on the ontario ca airport'}]}
# {'history_id': '200-4-4-5', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'yes', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'i dont know'}, {'question': 'do you need to make a booking are you travelling alone', 'answer': 'no i need the address of the airport in ontario canada'}]}
# {'history_id': '200-1-4-6', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no i need flight information for the airport', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'no i am looking for flight information for the airport'}, {'question': 'from which airport are you leaving', 'answer': 'i dont know'}]}
# {'history_id': '200-2-4-6', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just tell me which hotels are the closest to the airport', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'a map would help yes'}, {'question': 'from which airport are you leaving', 'answer': 'i need hotels information for the ontario ca airport area'}]}
# {'history_id': '200-3-4-6', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just what they offer', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'no i am looking for the service and facilites offered by the ontario canada airport'}, {'question': 'from which airport are you leaving', 'answer': 'no'}]}
# {'history_id': '200-4-4-6', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'yes', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'i dont know'}, {'question': 'from which airport are you leaving', 'answer': 'i need the address for the ontario canada airport'}]}
# {'history_id': '200-1-4-7', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no i need flight information for the airport', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'no i am looking for flight information for the airport'}, {'question': 'is there anywhere in california youd like to go visit', 'answer': 'no i need flight information for the airport in ontario'}]}
# {'history_id': '200-2-4-7', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just tell me which hotels are the closest to the airport', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'a map would help yes'}, {'question': 'is there anywhere in california youd like to go visit', 'answer': 'no canada'}]}
# {'history_id': '200-3-4-7', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just what they offer', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'no i am looking for the service and facilites offered by the ontario canada airport'}, {'question': 'is there anywhere in california youd like to go visit', 'answer': 'id like to know what services are available at the ontario ca airport'}]}
# {'history_id': '200-4-4-7', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'yes', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'i dont know'}, {'question': 'is there anywhere in california youd like to go visit', 'answer': 'the address of the ontario ca airport'}]}
# {'history_id': '200-1-4-8', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no i need flight information for the airport', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'no i am looking for flight information for the airport'}, {'question': 'what ammendities are you looking for in your airport', 'answer': 'no i want flight information not ammenity information'}]}
# {'history_id': '200-2-4-8', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just tell me which hotels are the closest to the airport', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'a map would help yes'}, {'question': 'what ammendities are you looking for in your airport', 'answer': 'i want to know what hotels are near'}]}
# {'history_id': '200-3-4-8', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just what they offer', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'no i am looking for the service and facilites offered by the ontario canada airport'}, {'question': 'what ammendities are you looking for in your airport', 'answer': 'i want informaion on the ontario ca airport ammendities'}]}
# {'history_id': '200-4-4-8', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'yes', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'i dont know'}, {'question': 'what ammendities are you looking for in your airport', 'answer': 'none i just need ontario cas airport address'}]}
# {'history_id': '200-1-4-9', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no i need flight information for the airport', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'no i am looking for flight information for the airport'}, {'question': 'would you like directions from your location', 'answer': 'would you like directions from your location'}]}
# {'history_id': '200-2-4-9', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just tell me which hotels are the closest to the airport', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'a map would help yes'}, {'question': 'would you like directions from your location', 'answer': 'no i just need the hotels near the airport in ontario ca'}]}
# {'history_id': '200-3-4-9', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just what they offer', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'no i am looking for the service and facilites offered by the ontario canada airport'}, {'question': 'would you like directions from your location', 'answer': 'no i would l like to know what services are offiered at the ontairo ca airport'}]}
# {'history_id': '200-4-4-9', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'yes', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'i dont know'}, {'question': 'would you like directions from your location', 'answer': 'yes please give me directions to the dmv'}]}
# {'history_id': '200-1-4-10', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no i need flight information for the airport', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'no i am looking for flight information for the airport'}, {'question': 'would you like to book a hotel there', 'answer': 'im looking for flight information for the ontario ca airport'}]}
# {'history_id': '200-2-4-10', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just tell me which hotels are the closest to the airport', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'a map would help yes'}, {'question': 'would you like to book a hotel there', 'answer': 'i would like to know the hotels near there'}]}
# {'history_id': '200-3-4-10', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just what they offer', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'no i am looking for the service and facilites offered by the ontario canada airport'}, {'question': 'would you like to book a hotel there', 'answer': 'no i would like to know what services are offered a the ontariaca airport'}]}
# {'history_id': '200-4-4-10', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'yes', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'i dont know'}, {'question': 'would you like to book a hotel there', 'answer': 'no thanks i would like the address of the place only'}]}
# {'history_id': '200-1-4-11', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no i need flight information for the airport', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'no i am looking for flight information for the airport'}, {'question': 'would you like to buy tickets to california', 'answer': 'yes'}]}
# {'history_id': '200-2-4-11', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just tell me which hotels are the closest to the airport', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'a map would help yes'}, {'question': 'would you like to buy tickets to california', 'answer': 'no i need to know which hotels are in the area of ontario ca airport'}]}
# {'history_id': '200-3-4-11', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just what they offer', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'no i am looking for the service and facilites offered by the ontario canada airport'}, {'question': 'would you like to buy tickets to california', 'answer': 'no i want to know the facilities and services at ontario california airport'}]}
# {'history_id': '200-4-4-11', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'yes', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'i dont know'}, {'question': 'would you like to buy tickets to california', 'answer': 'no'}]}
# {'history_id': '200-1-4-12', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no i need flight information for the airport', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'no i am looking for flight information for the airport'}, {'question': 'would you like to know more about ontarioca airport services', 'answer': 'if it contains flight info'}]}
# {'history_id': '200-2-4-12', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just tell me which hotels are the closest to the airport', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'a map would help yes'}, {'question': 'would you like to know more about ontarioca airport services', 'answer': 'no want to know about hotels near the airport'}]}
# {'history_id': '200-3-4-12', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just what they offer', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'no i am looking for the service and facilites offered by the ontario canada airport'}, {'question': 'would you like to know more about ontarioca airport services', 'answer': 'yes what type of services do they offer there'}]}
# {'history_id': '200-4-4-12', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'yes', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'i dont know'}, {'question': 'would you like to know more about ontarioca airport services', 'answer': 'no i need to know the exact address of where the ontario ca airport'}]}
# {'history_id': '200-1-4-13', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no i need flight information for the airport', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'no i am looking for flight information for the airport'}, {'question': 'would you like to know more about arrivals or departures', 'answer': 'yes that would be perfect'}]}
# {'history_id': '200-2-4-13', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just tell me which hotels are the closest to the airport', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'a map would help yes'}, {'question': 'would you like to know more about arrivals or departures', 'answer': 'no'}]}
# {'history_id': '200-3-4-13', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just what they offer', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'no i am looking for the service and facilites offered by the ontario canada airport'}, {'question': 'would you like to know more about arrivals or departures', 'answer': 'no i am not intested in fligjt data m'}]}
# {'history_id': '200-4-4-13', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'yes', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'i dont know'}, {'question': 'would you like to know more about arrivals or departures', 'answer': 'no just tell me the address'}]}
# {'history_id': '200-1-4-14', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no i need flight information for the airport', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'no i am looking for flight information for the airport'}, {'question': 'are you interested in visiting ontario california airport', 'answer': 'yes i need flight information'}]}
# {'history_id': '200-2-4-14', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just tell me which hotels are the closest to the airport', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'a map would help yes'}, {'question': 'are you interested in visiting ontario california airport', 'answer': 'no i want hotels close to the airport'}]}
# {'history_id': '200-3-4-14', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just what they offer', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'no i am looking for the service and facilites offered by the ontario canada airport'}, {'question': 'are you interested in visiting ontario california airport', 'answer': 'maybe'}]}
# {'history_id': '200-4-4-14', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'yes', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'i dont know'}, {'question': 'are you interested in visiting ontario california airport', 'answer': 'the airport can be found at 2500 east airport drive'}]}
# {'history_id': '200-1-4-16', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no i need flight information for the airport', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'no i am looking for flight information for the airport'}, {'question': 'would you like to book a flight at ontario california airport', 'answer': 'no i just need info'}]}
# {'history_id': '200-2-4-16', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just tell me which hotels are the closest to the airport', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'a map would help yes'}, {'question': 'would you like to book a flight at ontario california airport', 'answer': 'no'}]}
# {'history_id': '200-3-4-16', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just what they offer', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'no i am looking for the service and facilites offered by the ontario canada airport'}, {'question': 'would you like to book a flight at ontario california airport', 'answer': 'no i want to know about their services and facilities'}]}
# {'history_id': '200-4-4-16', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'yes', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'i dont know'}, {'question': 'would you like to book a flight at ontario california airport', 'answer': 'no i just need the address'}]}
# {'history_id': '200-1-4-17', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no i need flight information for the airport', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'no i am looking for flight information for the airport'}, {'question': 'would you like to hear departure times for ontario california airport', 'answer': 'no i need flight information'}]}
# {'history_id': '200-2-4-17', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just tell me which hotels are the closest to the airport', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'a map would help yes'}, {'question': 'would you like to hear departure times for ontario california airport', 'answer': 'i need to find a hotel near ontario airport in california'}]}
# {'history_id': '200-3-4-17', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just what they offer', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'no i am looking for the service and facilites offered by the ontario canada airport'}, {'question': 'would you like to hear departure times for ontario california airport', 'answer': 'no im looking for services available'}]}
# {'history_id': '200-4-4-17', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'yes', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'i dont know'}, {'question': 'would you like to hear departure times for ontario california airport', 'answer': 'i just need the ontario ca airports address'}]}
# {'history_id': '200-1-4-18', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no i need flight information for the airport', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'no i am looking for flight information for the airport'}, {'question': 'would you like to hear nes about ontario california airport', 'answer': 'no i am seeking flight information for the airport in ontario canada'}]}
# {'history_id': '200-2-4-18', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just tell me which hotels are the closest to the airport', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'a map would help yes'}, {'question': 'would you like to hear nes about ontario california airport', 'answer': 'no i am interested in hotels located near the airport in ontario ca'}]}
# {'history_id': '200-3-4-18', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just what they offer', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'no i am looking for the service and facilites offered by the ontario canada airport'}, {'question': 'would you like to hear nes about ontario california airport', 'answer': 'no'}]}
# {'history_id': '200-4-4-18', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'yes', 'history_list': [{'question': 'do you need a map of the area would you like the website address', 'answer': 'i dont know'}, {'question': 'would you like to hear nes about ontario california airport', 'answer': 'no just the address'}]}
# {'history_id': '200-1-5-6', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no i need flight information for the airport', 'history_list': [{'question': 'do you need to make a booking are you travelling alone', 'answer': 'i would like to find flight information'}, {'question': 'from which airport are you leaving', 'answer': 'i dont know'}]}
# {'history_id': '200-2-5-6', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just tell me which hotels are the closest to the airport', 'history_list': [{'question': 'do you need to make a booking are you travelling alone', 'answer': 'i need ontario hotel info'}, {'question': 'from which airport are you leaving', 'answer': 'i need hotels information for the ontario ca airport area'}]}
# {'history_id': '200-3-5-6', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just what they offer', 'history_list': [{'question': 'do you need to make a booking are you travelling alone', 'answer': 'i need facility information on the ontario ca airport'}, {'question': 'from which airport are you leaving', 'answer': 'no'}]}
# {'history_id': '200-4-5-6', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'yes', 'history_list': [{'question': 'do you need to make a booking are you travelling alone', 'answer': 'no i need the address of the airport in ontario canada'}, {'question': 'from which airport are you leaving', 'answer': 'i need the address for the ontario canada airport'}]}
# {'history_id': '200-1-5-7', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no i need flight information for the airport', 'history_list': [{'question': 'do you need to make a booking are you travelling alone', 'answer': 'i would like to find flight information'}, {'question': 'is there anywhere in california youd like to go visit', 'answer': 'no i need flight information for the airport in ontario'}]}
# {'history_id': '200-2-5-7', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just tell me which hotels are the closest to the airport', 'history_list': [{'question': 'do you need to make a booking are you travelling alone', 'answer': 'i need ontario hotel info'}, {'question': 'is there anywhere in california youd like to go visit', 'answer': 'no canada'}]}
# {'history_id': '200-3-5-7', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just what they offer', 'history_list': [{'question': 'do you need to make a booking are you travelling alone', 'answer': 'i need facility information on the ontario ca airport'}, {'question': 'is there anywhere in california youd like to go visit', 'answer': 'id like to know what services are available at the ontario ca airport'}]}
# {'history_id': '200-4-5-7', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'yes', 'history_list': [{'question': 'do you need to make a booking are you travelling alone', 'answer': 'no i need the address of the airport in ontario canada'}, {'question': 'is there anywhere in california youd like to go visit', 'answer': 'the address of the ontario ca airport'}]}
# {'history_id': '200-1-5-8', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no i need flight information for the airport', 'history_list': [{'question': 'do you need to make a booking are you travelling alone', 'answer': 'i would like to find flight information'}, {'question': 'what ammendities are you looking for in your airport', 'answer': 'no i want flight information not ammenity information'}]}
# {'history_id': '200-2-5-8', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just tell me which hotels are the closest to the airport', 'history_list': [{'question': 'do you need to make a booking are you travelling alone', 'answer': 'i need ontario hotel info'}, {'question': 'what ammendities are you looking for in your airport', 'answer': 'i want to know what hotels are near'}]}
# {'history_id': '200-3-5-8', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just what they offer', 'history_list': [{'question': 'do you need to make a booking are you travelling alone', 'answer': 'i need facility information on the ontario ca airport'}, {'question': 'what ammendities are you looking for in your airport', 'answer': 'i want informaion on the ontario ca airport ammendities'}]}
# {'history_id': '200-4-5-8', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'yes', 'history_list': [{'question': 'do you need to make a booking are you travelling alone', 'answer': 'no i need the address of the airport in ontario canada'}, {'question': 'what ammendities are you looking for in your airport', 'answer': 'none i just need ontario cas airport address'}]}
# {'history_id': '200-1-5-9', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no i need flight information for the airport', 'history_list': [{'question': 'do you need to make a booking are you travelling alone', 'answer': 'i would like to find flight information'}, {'question': 'would you like directions from your location', 'answer': 'would you like directions from your location'}]}
# {'history_id': '200-2-5-9', 'query': 'ontario california airport', 'question': 'do you need directions to ontario california airport', 'answer': 'no just tell me which hotels are the closest to the airport', 'history_list': [{'question': 'do you need to make a booking are you travelling alone', 'answer': 'i need ontario hotel info'}, {'question': 'would you like directions from your location', 'answer': 'no i just need the hotels near the airport in ontario ca'}]}
# ...
# {'history_id': '200-3-13-15', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no', 'history_list': [{'question': 'would you like to know more about arrivals or departures', 'answer': 'no i am not intested in fligjt data m'}, {'question': 'do you need directions to ontario california airport', 'answer': 'no just what they offer'}]}
# {'history_id': '200-4-13-15', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no just the address', 'history_list': [{'question': 'would you like to know more about arrivals or departures', 'answer': 'no just tell me the address'}, {'question': 'do you need directions to ontario california airport', 'answer': 'yes'}]}
# {'history_id': '200-1-13-16', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no i am seeking flight information for the airport in ontario canada', 'history_list': [{'question': 'would you like to know more about arrivals or departures', 'answer': 'yes that would be perfect'}, {'question': 'would you like to book a flight at ontario california airport', 'answer': 'no i just need info'}]}
# {'history_id': '200-2-13-16', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no i am interested in hotels located near the airport in ontario ca', 'history_list': [{'question': 'would you like to know more about arrivals or departures', 'answer': 'no'}, {'question': 'would you like to book a flight at ontario california airport', 'answer': 'no'}]}
# {'history_id': '200-3-13-16', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no', 'history_list': [{'question': 'would you like to know more about arrivals or departures', 'answer': 'no i am not intested in fligjt data m'}, {'question': 'would you like to book a flight at ontario california airport', 'answer': 'no i want to know about their services and facilities'}]}
# {'history_id': '200-4-13-16', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no just the address', 'history_list': [{'question': 'would you like to know more about arrivals or departures', 'answer': 'no just tell me the address'}, {'question': 'would you like to book a flight at ontario california airport', 'answer': 'no i just need the address'}]}
# {'history_id': '200-1-13-17', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no i am seeking flight information for the airport in ontario canada', 'history_list': [{'question': 'would you like to know more about arrivals or departures', 'answer': 'yes that would be perfect'}, {'question': 'would you like to hear departure times for ontario california airport', 'answer': 'no i need flight information'}]}
# {'history_id': '200-2-13-17', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no i am interested in hotels located near the airport in ontario ca', 'history_list': [{'question': 'would you like to know more about arrivals or departures', 'answer': 'no'}, {'question': 'would you like to hear departure times for ontario california airport', 'answer': 'i need to find a hotel near ontario airport in california'}]}
# {'history_id': '200-3-13-17', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no', 'history_list': [{'question': 'would you like to know more about arrivals or departures', 'answer': 'no i am not intested in fligjt data m'}, {'question': 'would you like to hear departure times for ontario california airport', 'answer': 'no im looking for services available'}]}
# {'history_id': '200-4-13-17', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no just the address', 'history_list': [{'question': 'would you like to know more about arrivals or departures', 'answer': 'no just tell me the address'}, {'question': 'would you like to hear departure times for ontario california airport', 'answer': 'i just need the ontario ca airports address'}]}
# {'history_id': '200-1-14-15', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no i am seeking flight information for the airport in ontario canada', 'history_list': [{'question': 'are you interested in visiting ontario california airport', 'answer': 'yes i need flight information'}, {'question': 'do you need directions to ontario california airport', 'answer': 'no i need flight information for the airport'}]}
# {'history_id': '200-2-14-15', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no i am interested in hotels located near the airport in ontario ca', 'history_list': [{'question': 'are you interested in visiting ontario california airport', 'answer': 'no i want hotels close to the airport'}, {'question': 'do you need directions to ontario california airport', 'answer': 'no just tell me which hotels are the closest to the airport'}]}
# {'history_id': '200-3-14-15', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no', 'history_list': [{'question': 'are you interested in visiting ontario california airport', 'answer': 'maybe'}, {'question': 'do you need directions to ontario california airport', 'answer': 'no just what they offer'}]}
# {'history_id': '200-4-14-15', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no just the address', 'history_list': [{'question': 'are you interested in visiting ontario california airport', 'answer': 'the airport can be found at 2500 east airport drive'}, {'question': 'do you need directions to ontario california airport', 'answer': 'yes'}]}
# {'history_id': '200-1-14-16', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no i am seeking flight information for the airport in ontario canada', 'history_list': [{'question': 'are you interested in visiting ontario california airport', 'answer': 'yes i need flight information'}, {'question': 'would you like to book a flight at ontario california airport', 'answer': 'no i just need info'}]}
# {'history_id': '200-2-14-16', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no i am interested in hotels located near the airport in ontario ca', 'history_list': [{'question': 'are you interested in visiting ontario california airport', 'answer': 'no i want hotels close to the airport'}, {'question': 'would you like to book a flight at ontario california airport', 'answer': 'no'}]}
# {'history_id': '200-3-14-16', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no', 'history_list': [{'question': 'are you interested in visiting ontario california airport', 'answer': 'maybe'}, {'question': 'would you like to book a flight at ontario california airport', 'answer': 'no i want to know about their services and facilities'}]}
# {'history_id': '200-4-14-16', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no just the address', 'history_list': [{'question': 'are you interested in visiting ontario california airport', 'answer': 'the airport can be found at 2500 east airport drive'}, {'question': 'would you like to book a flight at ontario california airport', 'answer': 'no i just need the address'}]}
# {'history_id': '200-1-14-17', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no i am seeking flight information for the airport in ontario canada', 'history_list': [{'question': 'are you interested in visiting ontario california airport', 'answer': 'yes i need flight information'}, {'question': 'would you like to hear departure times for ontario california airport', 'answer': 'no i need flight information'}]}
# {'history_id': '200-2-14-17', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no i am interested in hotels located near the airport in ontario ca', 'history_list': [{'question': 'are you interested in visiting ontario california airport', 'answer': 'no i want hotels close to the airport'}, {'question': 'would you like to hear departure times for ontario california airport', 'answer': 'i need to find a hotel near ontario airport in california'}]}
# {'history_id': '200-3-14-17', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no', 'history_list': [{'question': 'are you interested in visiting ontario california airport', 'answer': 'maybe'}, {'question': 'would you like to hear departure times for ontario california airport', 'answer': 'no im looking for services available'}]}
# {'history_id': '200-4-14-17', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no just the address', 'history_list': [{'question': 'are you interested in visiting ontario california airport', 'answer': 'the airport can be found at 2500 east airport drive'}, {'question': 'would you like to hear departure times for ontario california airport', 'answer': 'i just need the ontario ca airports address'}]}
# {'history_id': '200-1-15-16', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no i am seeking flight information for the airport in ontario canada', 'history_list': [{'question': 'do you need directions to ontario california airport', 'answer': 'no i need flight information for the airport'}, {'question': 'would you like to book a flight at ontario california airport', 'answer': 'no i just need info'}]}
# {'history_id': '200-2-15-16', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no i am interested in hotels located near the airport in ontario ca', 'history_list': [{'question': 'do you need directions to ontario california airport', 'answer': 'no just tell me which hotels are the closest to the airport'}, {'question': 'would you like to book a flight at ontario california airport', 'answer': 'no'}]}
# {'history_id': '200-3-15-16', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no', 'history_list': [{'question': 'do you need directions to ontario california airport', 'answer': 'no just what they offer'}, {'question': 'would you like to book a flight at ontario california airport', 'answer': 'no i want to know about their services and facilities'}]}
# {'history_id': '200-4-15-16', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no just the address', 'history_list': [{'question': 'do you need directions to ontario california airport', 'answer': 'yes'}, {'question': 'would you like to book a flight at ontario california airport', 'answer': 'no i just need the address'}]}
# {'history_id': '200-1-15-17', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no i am seeking flight information for the airport in ontario canada', 'history_list': [{'question': 'do you need directions to ontario california airport', 'answer': 'no i need flight information for the airport'}, {'question': 'would you like to hear departure times for ontario california airport', 'answer': 'no i need flight information'}]}
# {'history_id': '200-2-15-17', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no i am interested in hotels located near the airport in ontario ca', 'history_list': [{'question': 'do you need directions to ontario california airport', 'answer': 'no just tell me which hotels are the closest to the airport'}, {'question': 'would you like to hear departure times for ontario california airport', 'answer': 'i need to find a hotel near ontario airport in california'}]}
# {'history_id': '200-3-15-17', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no', 'history_list': [{'question': 'do you need directions to ontario california airport', 'answer': 'no just what they offer'}, {'question': 'would you like to hear departure times for ontario california airport', 'answer': 'no im looking for services available'}]}
# {'history_id': '200-4-15-17', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no just the address', 'history_list': [{'question': 'do you need directions to ontario california airport', 'answer': 'yes'}, {'question': 'would you like to hear departure times for ontario california airport', 'answer': 'i just need the ontario ca airports address'}]}
# {'history_id': '200-1-16-17', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no i am seeking flight information for the airport in ontario canada', 'history_list': [{'question': 'would you like to book a flight at ontario california airport', 'answer': 'no i just need info'}, {'question': 'would you like to hear departure times for ontario california airport', 'answer': 'no i need flight information'}]}
# {'history_id': '200-2-16-17', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no i am interested in hotels located near the airport in ontario ca', 'history_list': [{'question': 'would you like to book a flight at ontario california airport', 'answer': 'no'}, {'question': 'would you like to hear departure times for ontario california airport', 'answer': 'i need to find a hotel near ontario airport in california'}]}
# {'history_id': '200-3-16-17', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no', 'history_list': [{'question': 'would you like to book a flight at ontario california airport', 'answer': 'no i want to know about their services and facilities'}, {'question': 'would you like to hear departure times for ontario california airport', 'answer': 'no im looking for services available'}]}
# {'history_id': '200-4-16-17', 'query': 'ontario california airport', 'question': 'would you like to hear nes about ontario california airport', 'answer': 'no just the address', 'history_list': [{'question': 'would you like to book a flight at ontario california airport', 'answer': 'no i just need the address'}, {'question': 'would you like to hear departure times for ontario california airport', 'answer': 'i just need the ontario ca airports address'}]}
